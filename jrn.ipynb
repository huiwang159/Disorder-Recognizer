# %% [markdown]
# # Disorder Recognizer
# This project aims to recognize disorders from biomedical text for the purposes of cohort-building and query-based case retrieval. The General Disorder Recognizer (GDR) detects general disorders from biomedical text, and maps them to their respective Concept Unique Identifiers (CUIs) in the Unified Medical Language System (UMLS). The Specific Disorder Recognizer (SDR) detects specific disorders that map to a custom-made or automatically-generated list of CUIs. The types of disorder that are recognized include:
# - Acquired abnormality
# - Anatomical abnormality
# - Cell or molecular dysfunction
# - Congenital abnormality
# - Disease or syndrome
# - Experimental model of disease
# - Finding
# - Injury or poisoning
# - Mental or behavioral dysfunction
# - Neoplastic process
# - Pathologic function
# - Sign or symptom
#
# The functions can be easily tweaked to recognize the following semantic groups:
# - Activities & behaviors
# - Anatomy
# - Chemicals & drugs
# - Concepts & ideas
# - Devices
# - Disorders
# - Genes & molecular sequences
# - Geographic areas
# - Living beings
# - Objects
# - Occupations
# - Organizations
# - Phenomena
# - Physiology
# - Procedures

# %% [markdown]
# ## Setup

# %%
import re
import tls # tls is short for tools.
            # tls.py contains functions for text cleaning.
import csv
import numpy
import pandas
pandas.set_option('display.max_colwidth', 0)

# %%
from py4j.java_gateway import JavaGateway # Metamap is a Java program.
gateway = JavaGateway() # Py4j provides a gateway to Metamap.
j = gateway.entry_point # j is short for Java.

# %% [markdown]
# ## Clean Data

# %%
org = pandas.read_csv('org.csv', encoding='latin-1') # org is short for original dataset.
org[:1]
# Out:
#     ID  \
# 0  1.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                FULLTEXT  \
# 0  Final Report\n\nCLINICAL INFORMATION: {age_number} year-old man trauma\n\nCOMPARISON: No previous.\n\nPreliminary report given by radiology resident on-call at 12:46 hours.\n\nFINDINGS: The patient is intubated and with an orogastric tube in place.\n\nAcute left convexity subdural hematoma extending from the anterior midline over the frontal\ntemporal and parietal convexities. Maximum thickness of space collection is 0.9 cm.\n\nBifrontal multiple hemorrhagic contusions involving the inferior surface of the right\nfrontal lobe extending into both supraorbital gyri.\n\nLeft superior frontal acute subarachnoid hemorrhage.\n\nLeft inferior parietal small subarachnoid/intraparenchymal bleed.\n\nComplex fracture of the right mastoid bone involving the middle ear. For better assessment,\nrefer to CT facial bones. Adjacent pneumocephalus adjacent to right transverse sinus.\n\nPresence of tiny air pockets adjacent to the right orbital roof. Suspicious for nondisplaced\nfracture along the orbital roof.\n\nIMPRESSION: Multi compartmental acute posttraumatic intracranial bleeds. Right temporal\nbone complex fractures.\n\n{e-signature}
#
#    TOTAL  EPIH  SUBDH  IPH  CONT  SAH  IVH   SG  Unnamed: 10  Unnamed: 11  \
# 0  4.0    0.0   1.0    1.0  1.0   1.0  0.0  0.0 NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0 NaN          NaN

# %% [markdown]
# ### Cleaner

# %%
"""
Args:
    _txt: text to process
    
Returns:
    Cleaned text
"""

def cln(_txt): # cln is short for clean.
    _txt = str(_txt).replace('\n\n', '.').replace('\n', ' ')
    _txt = re.sub(r'\.+', ".", _txt)
    _txt = re.sub(r'\,+', ".", _txt)
    return tls.nt_cln(_txt) # nt_cln is short for neat clean.
                            # nt_cln makes text neater,
                            # preserving both semantics and syntax.

# %% [markdown]
# #### Example

# %%
smp = org.iloc[0]['FULLTEXT'] # smp is short for sample.
print(smp)
# Out:
# Final Report
#
# CLINICAL INFORMATION: {age_number} year-old man trauma
#
# COMPARISON: No previous.
#
# Preliminary report given by radiology resident on-call at 12:46 hours.
#
# FINDINGS: The patient is intubated and with an orogastric tube in place.
#
# Acute left convexity subdural hematoma extending from the anterior midline over the frontal
# temporal and parietal convexities. Maximum thickness of space collection is 0.9 cm.
#
# Bifrontal multiple hemorrhagic contusions involving the inferior surface of the right
# frontal lobe extending into both supraorbital gyri.
#
# Left superior frontal acute subarachnoid hemorrhage.
#
# Left inferior parietal small subarachnoid/intraparenchymal bleed.
#
# Complex fracture of the right mastoid bone involving the middle ear. For better assessment,
# refer to CT facial bones. Adjacent pneumocephalus adjacent to right transverse sinus.
#
# Presence of tiny air pockets adjacent to the right orbital roof. Suspicious for nondisplaced
# fracture along the orbital roof.
#
# IMPRESSION: Multi compartmental acute posttraumatic intracranial bleeds. Right temporal
# bone complex fractures.
#
# {e-signature}

# %%
cln(smp)
# Out:
# 'final report . clinical information : { age _ number } year - old man trauma . comparison : no previous . preliminary report given by radiology resident on - call at 12 : 46 hours . findings : the patient is intubated and with an orogastric tube in place . acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities . maximum thickness of space collection is 0.9 cm . bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri . left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed . complex fracture of the right mastoid bone involving the middle ear . for better assessment . refer to ct facial bones . adjacent pneumocephalus adjacent to right transverse sinus . presence of tiny air pockets adjacent to the right orbital roof . suspicious for nondisplaced fracture along the orbital roof . impression : multi compartmental acute posttraumatic intracranial bleeds . right temporal bone complex fractures . { e - signature }'

# %%
org['i'] = org['ID']
org['rpr'] = org['FULLTEXT'].apply(cln) # rpr is short for report.
org['ttl'] = org['TOTAL']
org['eph'] = org['EPIH']
org['sdh'] = org['SUBDH']
org['iph'] = org['IPH']
org['cnt'] = org['CONT']
org['sah'] = org['SAH']
org['ivh'] = org['IVH']
org['sgh'] = org['SG']
dtt = org[['rpr', 'ttl', 'eph', 'sdh', 'iph', 'cnt', 'sah', 'ivh', 'sgh']][:99] # dtt is short for data.
for clm in ['ttl', 'eph', 'sdh', 'iph', 'cnt', 'sah', 'ivh', 'sgh']:
    dtt[clm] = dtt[clm].apply(lambda x:int(x))

# %%
dtt.to_csv('dtt.csv', encoding='latin-1', index=False, quoting=csv.QUOTE_NONNUMERIC)
dtt = pandas.read_csv('dtt.csv', encoding='latin-1') # dtt is short for data.
dtt[:1]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rpr  \
# 0  final report . clinical information : { age _ number } year - old man trauma . comparison : no previous . preliminary report given by radiology resident on - call at 12 : 46 hours . findings : the patient is intubated and with an orogastric tube in place . acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities . maximum thickness of space collection is 0.9 cm . bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri . left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed . complex fracture of the right mastoid bone involving the middle ear . for better assessment . refer to ct facial bones . adjacent pneumocephalus adjacent to right transverse sinus . presence of tiny air pockets adjacent to the right orbital roof . suspicious for nondisplaced fracture along the orbital roof . impression : multi compartmental acute posttraumatic intracranial bleeds . right temporal bone complex fractures . { e - signature }
#
#    ttl  eph  sdh  iph  cnt  sah  ivh  sgh
# 0  4    0    1    1    1    1    0    0

# %% [markdown]
# ### Abbreviation Expander

# %%
abbs = list(dtt.columns[2:]) # abbs is short for abbreviations.
abbs
# Out:
# ['eph', 'sdh', 'iph', 'cnt', 'sah', 'ivh', 'sgh']

# %%
dsrs = ['epidural hematoma', # dsrs is short for disorders.
 'subdural hematoma',
 'intraparenchymal hemorrhage',
 'contusion',
 'subarachnoid hemorrhage',
 'intraventricular hemorrhage',
 'subgaleal hematoma']
dsrs
# Out:
# ['epidural hematoma',
#  'subdural hematoma',
#  'intraparenchymal hemorrhage',
#  'contusion',
#  'subarachnoid hemorrhage',
#  'intraventricular hemorrhage',
#  'subgaleal hematoma']

# %%
def abb_exp(_txt, abbs=None, exps=None): # abb_exp is short for abbreviation expansion.
    if (abbs is None) or (exps is None) or (len(abbs)!=len(exps)):
        return _txt
    else:
        _rtr = _txt
        for i in range(len(abbs)):
            _rtr = _rtr.replace(abbs[i], exps[i])
        return _rtr

# %% [markdown]
# #### Example

# %%
tmp = dtt.loc[64]['rpr'].split('.')[1].strip()
tmp
# Out:
# 'clinical information : { age _ number } year - old woman fu sah / sdh please do ct head at 10 : 00 am'

# %%
abb_exp(tmp, abbs, dsrs)
# Out:
# 'clinical information : { age _ number } year - old woman fu subarachnoid hemorrhage / subdural hematoma please do ct head at 10 : 00 am'

# %% [markdown]
# ## Disorder Recognizers

# %% [markdown]
# ### General Disorder Recognizer (GDR)

# %%
"""
Args:
    _txt: text to process
    
Returns:
    Prints the sentence fragment and all disorders therein recognized by Metamap in the following format.
    Returns the corresponding list of CUIs
"""

def gdr(_txt, abbs=None, exps=None):
    if _txt == '':
        return ''
    _txt = abb_exp(_txt, abbs, exps)
    snts = re.split(',|\.', _txt)
    cuis = []
    for _snt in snts:
        if len(_snt)>2:
            print(_snt.strip())
            _dsr = j.dsr(_snt) # j.dsr is a function in hui.java that configures Metamap to 
                                # generate all derivational variants of a phrase for UMLS concept mapping.
                                # This may produce overmatches, but can be easily tweaked.
            if _dsr != '':
                print(_dsr)
            cuis += [_ln.split('\t')[2] for _ln in _dsr.split('\n') if _ln.split('\t')[0]=='1']
    return ' '.join(list(set(cuis)))

# %% [markdown]
# #### Example

# %%
gdr(dtt.iloc[0]['rpr'], abbs, dsrs)
# Out:
# final report
# clinical information : { age _ number } year - old man trauma
# 1	inpo	C0332666	old injury|old, trauma
# comparison : no previous
# preliminary report given by radiology resident on - call at 12 : 46 hours
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# findings : the patient is intubated and with an orogastric tube in place
# acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# maximum thickness of space collection is 0
# 1	fndg	C3842591	0%|0
# 9 cm
# bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri
# 1	inpo	C0559567	multiple bruising|multiple, bruising
# left superior frontal acute subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0333276	acute hemorrhage|acute, hemorrhage
# left inferior parietal small subarachnoid / intraparenchymal bleed
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, bleeds
# complex fracture of the right mastoid bone involving the middle ear
# 1	inpo	C0016658	fracture|fracture
# for better assessment
# refer to ct facial bones
# adjacent pneumocepidural hematomaalus adjacent to right transverse sinus
# presence of tiny air pockets adjacent to the right orbital roof
# suspicious for nondisplaced fracture along the orbital roof
# 1	fndg	C4050405	suspicious for malignancy|suspicious
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# impression : multi compartmental acute posttraumatic intracranial bleeds
# 1	fndg	C4049863	radiologic impression|impression
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleeds
# 1	patf	C0333276	acute hemorrhage|acute, bleeds
# right temporal bone complex fractures
# 1	inpo	C0016658	fracture|fractures
# { e - signature }
# 'C4049863 C0016658 C3842591 C1292769 C0333276 C0585058 C0749098 C4050405 C0151699 C0332666 C3835651 C0559567 C0038525'

# %% [markdown]
# ### Specific Disorder Recognizer (SDR)

# %% [markdown]
# ### CUI Recommender

# %%
"""
Args:
    _dsr: disorder name
    
Returns:
    Prints the UMLS CUI, map score (if greater than 925) , preferred name, and matched words
    Returns the list of recommended CUIs
"""

def rcm(_dsr): # rcm is short for recommender. _dsr is short for disorder.
    _rcm = j.rcm(_dsr)
    print(_rcm)
    return [_ln.split()[0] for _ln in _rcm.split('\n')] # _ln is short for line.

# %% [markdown]
# #### Example

# %%
rcm('subarachnoid hemorrhage')
# Out:
# C0038525	1000	subarachnoid hemorrhage|subarachnoid, hemorrhage
# C4039573	944	nontraumatic subarachnoid intracranial hemorrhage|nontraumatic, subarachnoid, intracranial, hemorrhage
# C0270192	925	perinatal subarachnoid hemorrhage|perinatal, subarachnoid, haemorrhage
# C0472383	925	subarachnoid hemorrhage, spontaneous|spontaneous, subarachnoid, hemorrhage
# C0475073	925	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# C0751530	925	subarachnoid hemorrhage, aneurysmal|aneurysmal, subarachnoid, hemorrhage
# C0795688	925	subarachnoid hemorrhage, intracranial|intracranial, subarachnoid, hemorrhage
# C1410400	925	nontraumatic subarachnoid hemorrhage, unspecified|nontraumatic, subarachnoid, hemorrhage
# C3838874	925	perimesencephalic subarachnoid hemorrhage|perimesencephalic, subarachnoid, hemorrhage
# C3839590	925	convexal subarachnoid hemorrhage|convexal, subarachnoid, hemorrhage
# ['C0038525',
#  'C4039573',
#  'C0270192',
#  'C0472383',
#  'C0475073',
#  'C0751530',
#  'C0795688',
#  'C1410400',
#  'C3838874',
#  'C3839590']

# %% [markdown]
# ### Keyword Filter

# %%
"""
Args:
    _txt: text to process
    _dsr: disorder name
    
Returns:
    Returns filtered text where each sentence contains the first word of the disorder
"""

def kyw_flt(_txt, _dsr): # flt for filter
    snts = _txt.split('.') # snts is short for sentences.
    wrds = _dsr.split(' ') # wrds is short for words.
    return '.'.join([_snt for _snt in snts if wrds[0] in _snt]).strip()

# %% [markdown]
# #### Example

# %%
tmp = dtt.iloc[0]['rpr'] # tmp is short for temporary.
tmp
# Out:
# 'final report . clinical information : { age _ number } year - old man trauma . comparison : no previous . preliminary report given by radiology resident on - call at 12 : 46 hours . findings : the patient is intubated and with an orogastric tube in place . acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities . maximum thickness of space collection is 0.9 cm . bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri . left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed . complex fracture of the right mastoid bone involving the middle ear . for better assessment . refer to ct facial bones . adjacent pneumocephalus adjacent to right transverse sinus . presence of tiny air pockets adjacent to the right orbital roof . suspicious for nondisplaced fracture along the orbital roof . impression : multi compartmental acute posttraumatic intracranial bleeds . right temporal bone complex fractures . { e - signature }'

# %%
kyw_flt(tmp, dsrs[4])
# Out:
# 'left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed'

# %% [markdown]
# ### SDR Creator

# %%
"""
Args:
    _dsr: disorder name
    _abb: abbreviation of disorder (optional)
    cuis: list of CUIs to match (optional)
    
Returns:
    Returns a function that detects the presence of _dsr 
"""

def sdr_crt(_dsr, abbs, exps, cuis=None): # sdr_crt is short for specific disorder recognizer creator.
    if cuis is None:
        cuis = rcm(_dsr)
    def sdr(_txt): # sdr is short for specific disorder recognizer.
        _txt = abb_exp(_txt, abbs, exps)
        snts = re.split(',|\.', _txt)
        mtm_cuis = []
        for _snt in snts:
            mtm_cuis += gdr(kyw_flt(_snt, _dsr)).split(' ')
        mtm_cuis = list(set(mtm_cuis))
        return int(len([cui for cui in mtm_cuis if cui in cuis])>0)
    return sdr

# %% [markdown]
# #### Example

# %%
sdh_sdr = sdr_crt(dsrs[4], abbs, dsrs) # subdh_sdr is short for subdural hematoma (SDH) specific disorder recognizer.
                                            # sdh is an abbreviation of subdural hematoma by inspection.
# Out:
# C0038525	1000	subarachnoid hemorrhage|subarachnoid, hemorrhage
# C4039573	944	nontraumatic subarachnoid intracranial hemorrhage|nontraumatic, subarachnoid, intracranial, hemorrhage
# C0270192	925	perinatal subarachnoid hemorrhage|perinatal, subarachnoid, haemorrhage
# C0472383	925	subarachnoid hemorrhage, spontaneous|spontaneous, subarachnoid, hemorrhage
# C0475073	925	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# C0751530	925	subarachnoid hemorrhage, aneurysmal|aneurysmal, subarachnoid, hemorrhage
# C0795688	925	subarachnoid hemorrhage, intracranial|intracranial, subarachnoid, hemorrhage
# C1410400	925	nontraumatic subarachnoid hemorrhage, unspecified|nontraumatic, subarachnoid, hemorrhage
# C3838874	925	perimesencephalic subarachnoid hemorrhage|perimesencephalic, subarachnoid, hemorrhage
# C3839590	925	convexal subarachnoid hemorrhage|convexal, subarachnoid, hemorrhage

# %% [markdown]
# #### Note
# The recommended list of CUIs for SDH contains many overmatches, so a list of CUIs to match is custom-made from the printed results above.

# %%
cuis = ['C0018946',
 'C0270087',
 'C0393494',
 'C0393495',
 'C0238156',
 'C0265080',
 'C0749095',
 'C0749098',
 'C0854700',
 'C1367166']

# %%
sdh_sdr = sdr_crt(dsrs[1], abbs, dsrs, cuis) # This SDR only recognizes CUIs from the custom-made list.

# %%
dtt['mtm_sdh'] = dtt['rpr'].apply(sdh_sdr)
# Out:
# acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# presence of a right sided subdural hematoma located along the right tentorial leaflet and extending into the right occipital and temporal lobes
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# extensive multi - compartmental intracranial hemorrhage including right - sided subdural hematoma
# 1	patf	C0151699	intracranial hemorrhages|intracranial, haemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# left temporal acute subdural hematoma and subarachnoid hemorrhage with no significant variation in comparison to previous study
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hemorrhage
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# bilateral anterior and posterior parasagittal craniotomies with underlying bilateral holohemispheric subdural hematomas
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# bilateral holohemispheric chronic subdural hematomas with no interval remarkable change in comparison to previous study from september 11
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, hematomas
# clinical information : 59m transfered from notre dame with right temporal lobe subdural + / - intracranial hemorrage ( initial ct 3 : 30 )
# 1	fndg	C3842588	30%|30
# clinical information : f / u subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# with left holohemispheric acute subdural hematoma with predominant involvement of the superior surface of the left tentorial leaflet and of the left occipitoparietal region
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# multi compartmental intracranial traumatic bleed with no interval significant change for the left holohemispheric acute subdural hematoma
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# 0	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left holohemispheric acute subdural hematoma involving the left leaflet of the cerebellar tentorium with interhemispheric occipitoparietal extension
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left holohemispheric acute subdural hematoma with predominant involvement of the surface of the tentorium
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# right temporal hemorrhagic contusion involving the inferior temporal gyrus with overlying subarachnoid hemorrhage and small acute subdural hematoma with maximal thickness measuring 4 mm
# 1	inpo	C0009938	contusions|contusion
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	fndg	C3842087	4 mm|4, mm
# left temporal acute subdural hematoma with maximal thickness measuring 6 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842086	6 mm|6, mm
# with lying the subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# right temporal acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left temporal acute subdural hematoma and traumatic subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# bilateral frontotemporal acute subdural hematomas with frontotemporal predominance
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# multi compartmental intracranial traumatic bleed with bilateral frontotemporal acute subdural hematomas
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# right frontal small subdural acute hematoma with maximal thickness measuring 3 mm
# 1	fndg	C1845250	small forehead|small, forehead
# 1	patf	C0749098	hematoma, subdural, acute|hematoma, subdural, acute
# 1	fndg	C3842088	3 mm|3, mm
# interval stability in the right frontal acute subdural hematoma and in the distribution of the subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# clinical information : controle subdural hematoma at 19h00
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# the on - call residents were concerned for a potential small subdural collection along the interhemispheric falx cerebri
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# a very small amount of subdural or subarachnoid blood along the falx is possible
# a definite subdural hematoma along the falx is not identified
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 0	fndg	C1550043	container status - identified|identified
# right frontal subdural pneumocepidural hematomaalus
# midline retroclival acute subdural hematoma with maximal thickness measuring 3
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3838680	3+ answer to question|3
# left frontal small subdural hematoma with maximal thickness measuring 4 mm
# 1	fndg	C1845250	small forehead|small, forehead
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842087	4 mm|4, mm
# subdural pneumocepidural hematomaalus
# retroclival acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left frontal acute subdural hematoma and small amount of traumatic subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# recent subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# the right temporoparietal small subdural hematoma is now isodense
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# follow - up study with interval resolution of the subarachnoid hemorrhage and expected evolution of the right temporoparietal subdural hematoma
# 1	patf	C1514893	physiologic resolution|resolution
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# interhemispheric and left frontal acute lobulated subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# interhemispheric subdural hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# interhemispheric left frontal acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# clinical information : f / u subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# the subdural hematomas over both cerebral convexities
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# there is an acute subdural hematoma over the left cerebral convexity measuring 8 mm in thickness
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# smaller subdural hematomas noted over the right parietal occipital convexity extending over the right tentorium
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# a smaller subdural hematomas noted in the right frontal region
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# there is an acute subdural hematoma over the left cerebral convexity
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# smaller subdural hematomas are noted in the right parieto - occipital and frontal regions as noted above
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# there is an acute subdural hematoma in the right parietal region
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# subdural hematoma over the right parietal convexity measuring 5 mm in thickness
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3840882	5 mm|5, mm
# further review of this case demonstrates the presence of a small subdural hematoma along the posterior falx cerebri measuring 4 mm in thickness
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842087	4 mm|4, mm
# acute left parasagittal occipitoparietal interhemispheric subdural hematoma with maximal thickness measuring 5 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3840882	5 mm|5, mm
# findings : small acute right temporoparietal subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# likely extending into the right posterior interhemispheric subdural space
# small right temporal subdural hematoma with acute blood products and maximal thickness measuring 1
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3816745	1+|1
# there is extensive bilateral subarachnoid hemorrhage as well as bilateral mainly frontal subdural hematomas
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# bilateral subdural and subarachnoid hemorrhage extends into basal cisterns
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# left temporal intraparenchymal contusion with subarachnoid and subdural extension and surrounding vasogenic edema causing mass effect and left hemispheric brain edema
# 1	inpo	C0009938	contusions|contusion
# 1	fndg	C2825502	vasogenic edema|vasogenic, edema
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	fndg	C0013604	edema|oedema
# clinical information : { age _ number } years old fu subdural hematoma please do ct head at 18 : 30 pm
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C0231337	senility|old, age
# 1	fndg	C3842588	30%|30
# 1	fndg	C4049155	infusion pump alert priority pm|pm
# left temporal acute subdural hematoma with maximal thickness measuring 3 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842088	3 mm|3, mm
# right parietal interhemispheric acute small subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# follow - up study with interval mild increase in the subarachnoid hemorrhage and interval stability of the left temporal acute subdural hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# parietal interhemispheric acute subdural hematoma and left temporal parenchymal hemorrhagic contusions
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	patf	C0747264	parenchymal hemorrhage|parenchymal, hemorrhage
# 1	inpo	C0009938	contusions|contusions
# left temporal subdural hematoma with maximal thickness of 3 mm and left inferior temporal small contusion
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842088	3 mm|3, mm
# 1	inpo	C0009938	contusions|contusion
# small right subarachnoid and interhemispheric subdural falcine hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# clinical information : { age _ number } years old fu subdural hematoma / subarachnoid hemorrhage on coumadin please do ct head at 6 : 00 pm
# 1	fndg	C0231337	senility|old, age
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	fndg	C4049155	infusion pump alert priority pm|pm
# no remarkable changes in the appearance of the right temporo - occipital acute subdural hematoma and with interval stability of the subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 0	patf	C1997213	occipital subdural hematoma|occipital, subdural, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# small r subdural hematoma + subarachnoid hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# right frontal subdural collection
# right frontoparietal subacute subdural hematoma with acute blood products and no interval remarkable change in comparison to previous head ct from the same day earlier
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# small acute right temporal / occipital subdural hematoma with maximal thickness measuring 2 mm and associated subarachnoid hemorrhage
# 1	patf	C1997213	occipital subdural hematoma|occipital, subdural, hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842089	2 mm|2, mm
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# right temporal occipital acute small subdural hematoma with mild mass effect
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	patf	C1997213	occipital subdural hematoma|occipital, subdural, hematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# right lateral convexity subdural hematoma with maximal thickness of 0
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842591	0%|0
# bilateral holohemispheric chronic subdural hematomas with acute rebleeding
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, hematomas
# bilateral chronic holohemispheric subdural hematomas with acute rebleeding and asymmetric mass effect
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, hematomas
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# no significant changes of the bilateral holohemispheric subdural hematomas with supratentorial extension
# 0	patf	C0018946	hematoma, subdural|subdural, hematomas
# bilateral subdural hematomas
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# right acute holohemispheric subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left chronic holohemispheric subdural hematoma with acute rebleeding
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# the subdural hematomas over the left cerebral convexity and along the falx cerebri and straight no significant changes
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# clinical information : f / u subarachnoid hemorrhage and subdural hematoma
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# there is an acute left subdural hematoma over the left frontal temporoparietal convexity
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# a smaller subdural hematoma found along the posterior aspect of the falx cerebri is also stable
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# there is a right holohemispheric acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# small subdural hematomas are noted tracking over the right side of the tentorium and along the falx cerebri measuring up to 4 mm in thickness
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# there is also a small subdural hematoma over the left frontotemporal convexity measuring 3 mm in thickness
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842088	3 mm|3, mm
# resulting in presence of a large right holohemispheric subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# smaller subdural hematomas are seen along the falx cerebri and tentorium cerebellum and in the left frontotemporal region
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# there is interval stability of the acute left temporoparietal subdural hematoma with extension over the left tentorial leaflet
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left parietal acute subdural hematoma with maximal thickness measuring 8 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# multi compartmental traumatic bleed with left parietal acute subdural hematoma
# 1	inpo	C0040797	traumatic hemorrhage|traumatic, bleeds
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left temporoparietal acute subdural hematoma with maximal thickness at the level of the parietal component
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left holohemispheric acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# clinical information : { age _ number } years old follow - up traumatic subarachnoid hemorrhage / subdural hematoma
# 1	fndg	C0231337	senility|old, age
# 1	fndg	C0589120	follow-up status|follow, up
# 1	inpo	C0475059	subdural hematoma, traumatic|traumatic, subdural, haematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	inpo	C0475060	intracranial subdural hematoma, traumatic|traumatic, subdural, hematoma
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# bilateral frontoparietal chronic subdural hematomas with left acute rebleeding
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, hematomas
# clinical information : 39m f / u subdural hematoma and subarachnoid hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# redemonstration of acute subdural hematoma involving the left temporal region
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# small acute subdural hematoma with maximal thickness measuring 2
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3833492	2+|2
# small acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# possible left parasagittal upper frontal subdural hematoma with adjacent subarachnoid bleed
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	patf	C0019080	hemorrhage|bleeds
# bilateral acute subdural hematomas with frontal and temporal extension
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# bilateral acute subdural hematomas and subarachnoid hemorrhage with secondary midline shift to the right
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	neop	C0027627	neoplasm metastasis|secondary
# small posterior left parietal subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# small right parafalcine subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# right holohemispheric chronic subdural hematoma with some areas of acute rebleeding and maximal thickness of 22 mm with mass effect and midline shift to the left measuring 7 mm and right uncal herniation
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	acab	C0393985	uncinate herniation|uncal, herniation
# left holohemispheric subdural collection with maximal thickness measuring 6 mm
# 1	fndg	C3842086	6 mm|6, mm
# right holohemispheric chronic subdural hematoma with acute rebleeding and significant interval increase in the volume and mass effect with midline shift to the left and uncal herniation
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	acab	C0393985	uncinate herniation|uncal, herniation
# interval reduction in the volume of the left holohemispheric chronic subdural hematoma
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# clinical information : { age _ number } year - old woman fu subarachnoid hemorrhage / subdural hematoma please do ct head at 10 : 00 am
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	fndg	C0231337	senility|old, age
# 1	fndg	C3842590	10%|10
# clinical information : { age _ number } years old f / u subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C0231337	senility|old, age
# tiny right anterior parasagittal acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# traumatic subarachnoid hemorrhage involving right frontal sulci and the adjacent parasagittal subdural space
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# left holohemispheric acute subdural hematoma with maximal thickness of 22 mm and mass effect over the underlying brain parenchyma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# left holohemispheric acute subdural hematoma with secondary midline shift to the right and left descending transtentorial herniation with mass effect over the brainstem
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	neop	C0027627	neoplasm metastasis|secondary
# 1	acab	C2937226	transtentorial hernia|transtentorial, herniation
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# follow - up ct angiogram after the subdural drainage is recommended
# 1	fndg	C0589120	follow-up status|follow, up
# small interhemispheric subdural hematoma with thickness up to 4 mm
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# interhemispheric subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# the previously described small subdural collection over the right paracentral lobule has decreased in size
# there is no significant widening of the subarachnoid or subdural space over the left cerebral convexity
# left frontal parafalcine thin acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left parasagittal interhemispheric acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# small acute left temporal subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# interval mild increase in the subarachnoid hemorrhage and interval stability in the left temporal acute subdural hematoma and in the left temporal lobe hemorrhagic contusions
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	inpo	C0009938	contusions|contusions
# follow - up study with interval stability in the volume of the left chronic frontal parietal subdural hematoma with mild increase in acute blood
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# follow - up study with interval stability in the volume of the left frontoparietal chronic subdural hematoma with mild acute rebleeding
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# small acute subdural hematoma with maximal thickness of 3 mm in the right temporal region
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842088	3 mm|3, mm
# small acute right temporal subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# a chronic left convexity subdural hematoma with maximum diameter of 6 mm is identified and appears unchanged compared to previous
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C3842086	6 mm|6, mm
# 1	fndg	C1550043	container status - identified|identified
# 1	fndg	C0442739	no status change|unchanged
# thin right sided subdural hematoma over the right temporal lobe which has mildly redistributed over the parietal lobe
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# thin right - sided subdural hematoma with acute blood products now seen over the temporal and parietal lobes
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# small amount of overlying subarachnoid hemorrhage and thin left - sided subdural hematoma
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# a low density component of the subdural collection has likely redistributed slightly posteriorly over the parietal lobe
# thin acute subdural hematoma over the right temporal lobe measuring 3 mm in thickness
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842088	3 mm|3, mm
# thin acute subdural hematoma over the right temporal lobe
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# small amount of overlying subarachnoid hemorrhage and thin subdural hematoma
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# left frontoparietal chronic subdural hematoma with acute rebleeding and maximal thickness of 5 mm with mild mass effect
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C3840882	5 mm|5, mm
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# left frontoparietal chronic subdural hematoma with acute rebleeding and mild mass effect
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# bilateral holohemispheric acute subdural hematomas with maximal thickness on the left of 6 mm and on the right of 4 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# 1	fndg	C3842086	6 mm|6, mm
# 1	fndg	C3842087	4 mm|4, mm
# bilateral holohemispheric acute subdural hematomas
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# left sided subdural hematoma has redistributed now being holohemispheric
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# interhemispheric thin bilateral tentorial subdural hematomas
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# thin right posterior parafalcine subdural hematoma without significant mass effect
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 0	fndg	C0577559	mass of body structure|mass
# 0	sosy	C0577573	mass of body region|mass

# %%
mtm_abbs = ['mtm_'+abb for abb in abbs] # mtm_abbs is short for Metamap recognition of the disorder of the abbreviation.
mtm_abbs
# Out:
# ['mtm_eph', 'mtm_sdh', 'mtm_iph', 'mtm_cnt', 'mtm_sah', 'mtm_ivh', 'mtm_sgh']

# %%
sdh_err = dtt[dtt[mtm_abbs[1]]!=dtt[abbs[1]]].copy() # subdh_err is short for subdural hematoma errors.
sdh_err['flt'] = sdh_err['rpr'].apply(lambda _x:kyw_flt(abb_exp(_x, abbs, dsrs), dsrs[1]))
sdh_err[['flt', abbs[1], mtm_abbs[1]]]
# Out:
#                                                                                                                                                                                                                      flt  \
# 32  left temporal intraparenchymal contusion with subarachnoid and subdural extension and surrounding vasogenic edema causing mass effect and left hemispheric brain edema
# 41  no significant changes of the bilateral holohemispheric subdural hematomas with supratentorial extension
# 64  clinical information : { age _ number } year - old woman fu subarachnoid hemorrhage / subdural hematoma please do ct head at 10 : 00 am
# 71  the previously described small subdural collection over the right paracentral lobule has decreased in size . there is no significant widening of the subarachnoid or subdural space over the left cerebral convexity
#
#     sdh  mtm_sdh
# 32  1    0
# 41  1    0
# 64  0    1
# 71  1    0

# %% [markdown]
# #### Accuracy

# %%
numpy.round(1-len(sdh_err)/len(dtt), 2)
# Out:
# 0.96

# %% [markdown]
# ## Application
# Here, we apply GDR to the whole dataset, and compared the results to the dataset labels.

# %%
dtt['dsrs'] = dtt['rpr'].apply(lambda _txt : gdr(_txt, abbs, dsrs))
# Out:
# final report
# clinical information : { age _ number } year - old man trauma
# 1	inpo	C0332666	old injury|old, trauma
# comparison : no previous
# preliminary report given by radiology resident on - call at 12 : 46 hours
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# findings : the patient is intubated and with an orogastric tube in place
# acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# maximum thickness of space collection is 0
# 1	fndg	C3842591	0%|0
# 9 cm
# bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri
# 1	inpo	C0559567	multiple bruising|multiple, bruising
# left superior frontal acute subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0333276	acute hemorrhage|acute, hemorrhage
# left inferior parietal small subarachnoid / intraparenchymal bleed
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, bleeds
# complex fracture of the right mastoid bone involving the middle ear
# 1	inpo	C0016658	fracture|fracture
# for better assessment
# refer to ct facial bones
# adjacent pneumocepidural hematomaalus adjacent to right transverse sinus
# presence of tiny air pockets adjacent to the right orbital roof
# suspicious for nondisplaced fracture along the orbital roof
# 1	fndg	C4050405	suspicious for malignancy|suspicious
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# impression : multi compartmental acute posttraumatic intracranial bleeds
# 1	fndg	C4049863	radiologic impression|impression
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleeds
# 1	patf	C0333276	acute hemorrhage|acute, bleeds
# right temporal bone complex fractures
# 1	inpo	C0016658	fracture|fractures
# { e - signature }
# final report
# clinical information : { age _ number } year - old man nonintubated trauma assaulted n intox
# 1	inpo	C0332666	old injury|old, trauma
# comparison : no previous
# preliminary report given by radiologist on - call at 07 : 05 hours
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# findings : the major arteries and veins show opacification related to previous intravenous contrast administration for neck ct
# 1	fndg	C0445223	related personal status|related
# no intracranial hematomas
# 0	patf	C0018944	hematoma|hematomas
# no depressed calvarial fractures
# 0	inpo	C0332759	depressed fracture|depressed, fractures
# no fluid levels in the mastoid bones
# the paranasal sinuses appear clear
# 1	fndg	C1709157	negative surgical margin|clear
# impression : no evidence of acute intracranial posttraumatic sequelae
# 1	fndg	C4049863	radiologic impression|impression
# 0	patf	C0243088	sequelae aspects|sequelae
# 0	fndg	C0543419	sequela of disorder|sequelae
# note : small posttraumatic subarachnoid bleed could be missed in the presence of recent intravenous contrast injection
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, bleeds
# { e - signature }
# final report
# clinical information : { age _ number } years old reassess intraparenchymal bleed - stable vs progressing
# 1	patf	C0019080	hemorrhage|bleed
# comparison :
# previous head ct from the same day earlier
# findings :
# bilateral frontal and temporal hemorrhagic contusions with interval stability in comparison to previous
# 1	inpo	C0009938	contusions|contusions
# traumatic subarachnoid hemorrhage with extension into the posterior horn of the right lateral ventricle
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# no midline shift
# bifrontal hygromas
# 1	neop	C0206620	lymphangioma, cystic|hygromas
# redemonstration of nondisplaced left frontal fracture
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# follow - up study with interval stability of the bilateral frontal and temporal hemorrhagic contusions
# 1	inpo	C0009938	contusions|contusions
# also stability in the traumatic subarachnoid hemorrhage and bilateral frontal hygromas
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# 1	neop	C0206620	lymphangioma, cystic|hygromas
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old fall from own height
# 1	fndg	C0085639	falls|fall
# 1	fndg	C0231337	senility|old, age
# comparison :
# findings :
# right frontal subgaleal hematoma with underlying nondisplaced fracture involving the vertical portion of the left frontal bone
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 1	inpo	C0016658	fracture|fractures
# right parietal subgaleal hematoma
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# left frontal traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# bifrontal hygromas
# 1	neop	C0206620	lymphangioma, cystic|hygromas
# hemorrhagic contusions involving the supra orbital frontal gyri
# 1	inpo	C0009938	contusions|contusions
# otherwise the gray and white matter differentiation is preserved
# no midline shift
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# bifrontal supraorbital hemorrhagic contusions
# 1	inpo	C0578447	supraorbital bruise|supraorbital, bruise
# left frontal nondisplaced fracture with overlying subgaleal hematoma
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# bilateral hygromas
# 1	neop	C0206620	lymphangioma, cystic|hygromas
# { e - signature }
# { e - signature }
# final report
# ct scan of the head without contrast
# clinical information : { age _ number } year - old { gender } trauma
# 1	inpo	C0332666	old injury|old, trauma
# comparison : no previous available for comparison
# findings :
# patient is intubated and has an orogastric feeding tube
# there is extensive multi - compartmental intracranial hemorrhage
# 1	patf	C0151699	intracranial hemorrhages|intracranial, haemorrhage
# presence of a right sided subdural hematoma located along the right tentorial leaflet and extending into the right occipital and temporal lobes
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# it measures up to 11 mm in maximal diameter
# presence of at least 5 foci of intraparenchymal hemorrhage surrounded by vasogenic edema with the largest measuring 1
# 1	patf	C0019080	hemorrhage|hemorrhage
# 1	fndg	C2825502	vasogenic edema|vasogenic, edema
# 1	fndg	C3816745	1+|1
# 6 x 1
# 1 cm in the right temporal lobe and 1
# 1	fndg	C3816745	1+|1
# 2 x 1
# 2 cm in the left thalamic region
# 1	fndg	C3833492	2+|2
# multiple bilateral foci of subarachnoid hemorrhage in particular within the left sylvian fissure and bilateral anterior frontal sulci
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# there is extension of blood into the ventricular system notably seen in the right lateral ventricle
# left peri - pontine cisterns
# interpeduncular cistern and aqueduct of sylvius
# there is also hemorrhage seen tracking down into the foramen magnum and cervical canal ( image 5
# 1	patf	C0019080	hemorrhage|hemorrhage
# series 5 )
# scattered foci of bleeding is noted at the gray - white matter junction bilaterally
# 1	patf	C0019080	hemorrhage|bleeding
# in particular in the right frontal region ( image 53
# series 5 ) and in the splenium of the corpus callosum
# these lesions are suggestive of diffuse axonal injury
# 1	fndg	C0221198	lesion|lesions
# 1	inpo	C0752219	diffuse axonal injury|diffuse, axonal, injury
# there is generalized edema with fuse effacement of sulci bilaterally
# 1	patf	C0151603	anasarca|generalized, oedema
# 1	fndg	C1850534	edema, generalized|generalised, oedema
# 1	fndg	C3887935	polykaryocytosis inducer|fuse
# compression of the ventricular system and partial obliteration of the basal cisterns
# early uncal herniation is suspected
# 1	acab	C0393985	uncinate herniation|uncal, herniation
# no tonsillar herniation
# 0	acab	C0393983	hernia of cerebellar tonsil into foramen magnum|tonsillar, herniation
# 0	dsyn	C0393983	hernia of cerebellar tonsil into foramen magnum|tonsillar, herniation
# right petrous temporal bone fracture with mastoid effusions and hemotympanum
# 1	inpo	C0272461	fracture of temporal bone|temporal, bone, fracture
# 1	inpo	C0435278	petrous bone fracture|petrous, bone, fracture
# 1	inpo	C0016658	fracture|fracture
# 1	patf	C0013687	effusion|effusions
# 1	dsyn	C0019125	hematotympanum|hemotympanum
# associated pneumocepidural hematomaalus underlying the right temporal bone fracture
# 1	inpo	C0272461	fracture of temporal bone|temporal, bone, fracture
# 1	inpo	C0016658	fracture|fracture
# recommend ct scan of the temporal bones for more detailed assessment
# additionally
# there is a suspected irregularity of the left lambdoid suture with multiple underlying foci of pneumocepidural hematomaalus which could represent possible suture diastasis
# 1	patf	C0036679	diastasis|diastasis
# significant subcutaneous soft tissue swelling and subcutaneous emphysema in the right periorbital region
# 1	patf	C0038536	subcutaneous emphysema|subcutaneous, emphysema
# 1	dsyn	C0037580	soft tissue swelling|soft, tissue, swelling
# no associated globe injury
# 0	inpo	C0015408	eye injuries|globe, injury
# 0	inpo	C0339055	injury of globe of eye|globe, injury
# however
# there is right globe exophthalmos with mild right retrobulbar fat stranding
# 1	dsyn	C0015300	exophthalmos|exophthalmus
# prominent optic nerve sheaths bilaterally which could be related to increased intracranial pressure
# 1	fndg	C0445223	related personal status|related
# 1	dsyn	C0151740	intracranial hypertension|increased, intracranial, pressure
# multiple extensive bilateral facial bone fractures are present involving involving the right posterolateral
# 1	inpo	C0159321	fracture of face bones|bones, facial, fractures
# right anteromedial and left posterolateral sinus walls
# there is a depressed and displaced right nasal bone fracture
# 1	inpo	C0332759	depressed fracture|depressed, fracture
# 1	fndg	C0344315	depressed mood|depressed
# 1	inpo	C0585059	fracture with displacement|displaced, fracture
# 1	fndg	C0549249	depressed level of consciousness|depressed
# also
# possible irregularity of the lamina papyracea bilaterally
# there is bilateral hemo - sinus in the maxillary sinuses and right sphenoid sinus
# 1	anab	C0016169	pathologic fistula|sinuses
# recommend ct scan of the facial bones for more detailed assessment
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# extensive multi - compartmental intracranial hemorrhage including right - sided subdural hematoma
# 1	patf	C0151699	intracranial hemorrhages|intracranial, haemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# bilateral intraparenchymal contusions
# 1	inpo	C0009938	contusions|contusions
# scattered bilateral subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# intraventricular hemorrhage and suspected diffuse external injury
# 1	patf	C0240059	ventricular hemorrhage|intraventricular, haemorrhage
# as described in the body report
# generalized edema with effacement of sulci
# 1	patf	C0151603	anasarca|generalized, oedema
# 1	fndg	C1850534	edema, generalized|generalised, oedema
# compression of the ventricular system and partial obliteration of basal cisterns
# right petrous temporal bone fracture with underlying pneumocepidural hematomaalus and large mastoid effusion and hemotympanum
# 1	inpo	C0272461	fracture of temporal bone|temporal, bone, fracture
# 1	inpo	C0435278	petrous bone fracture|petrous, bone, fracture
# 1	inpo	C0016658	fracture|fracture
# 1	dsyn	C0019125	hematotympanum|hemotympanum
# 1	patf	C0013687	effusion|effusion
# recommend further assessment with a dedicated ct scan of the temporal bones
# multiple bilateral extensive facial bone fractures with hemo - sinus
# 1	inpo	C0016658	fracture|fractures
# 1	anab	C0016169	pathologic fistula|sinuses
# recommend a dedicated ct scan of the facial bones for further assessment
# left occipital pneumocepidural hematomaalus with irregularity of the left lambdoid suture possibly representing suture diastases at this level
# a preliminary report was provided on september 26
# 2017 at 10 : 19
# 1	fndg	C3842590	10%|10
# { e - signature }
# { e - signature }
# final report
# clinical information : 74 yo
# f blunt trauma
# 1	inpo	C0043253	nonpenetrating wounds|blunt, trauma
# comparison :
# previous head ct available from the same day earlier
# findings :
# small amount of traumatic subarachnoid hemorrhage involving the right temporal and parietal sulci
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# the gray and white matter differentiation is preserved
# patchy hypodensities involving the supratentorial white matter
# no midline shift
# normal appearance of the ventricular system
# 1	fndg	C0332441	normal tissue morphology|normal, appearance
# 1	fndg	C1271005	normal appearance (finding)|normal, appearance
# right parietal subgaleal hematoma and emphysema with no evidence of underlying fracture
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 1	patf	C0013990	pathological accumulation of air in tissues|emphysema
# 1	dsyn	C0034067	pulmonary emphysema|emphysema
# 0	inpo	C0016658	fracture|fracture
# right sphenoidal hemosinus
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# traumatic subarachnoid hemorrhage involving the right temporal and parietal sulci
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# right parietal subgaleal hematoma with no evidence of underlying fracture
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 0	inpo	C0016658	fracture|fracture
# chronic microvascular white matter changes
# 1	fndg	C1833300	white matter changes|white, matter, changes
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old blunt trauma follow up
# 1	inpo	C0043253	nonpenetrating wounds|blunt, trauma
# 1	inpo	C0332666	old injury|old, trauma
# 1	fndg	C0231337	senility|old, age
# 1	fndg	C0589120	follow-up status|follow, up
# comparison :
# no previous head study available
# findings :
# right frontal temporal hemorrhagic contusions with no interval significant change
# 1	inpo	C0009938	contusions|contusions
# left temporal acute subdural hematoma and subarachnoid hemorrhage with no significant variation in comparison to previous study
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hemorrhage
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# no midline shift
# normal ventricular system
# 1	fndg	C0231683	gait normal|normal
# redemonstration of left temporal fracture
# 1	inpo	C0272461	fracture of temporal bone|temporal, fracture
# pneumocepidural hematomaalus
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# follow - up study with multi compartmental bleed with no interval significant change
# 1	patf	C0019080	hemorrhage|bleed
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old
# acute confusion hx of subarachnoid hemorrhage
# 1	fndg	C1285577	acute confusional state|acute, confusion
# 1	fndg	C0262926	medical history|hx
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# preliminary report was done by resident on call 17 : 57
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# previous head ct available from september 11
# findings :
# bilateral anterior and posterior parasagittal craniotomies with underlying bilateral holohemispheric subdural hematomas
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# and maximal thickness on the right measuring 15 mm and on the left measuring 7 mm
# no midline shift
# encepidural hematomaalomalacic changes involving the right supraorbital frontal gyri and the rectus gyrus and the right precentral frontal gyrus
# confluent hypodensities involving the supratentorial white matter
# chronic lacunar infarct involving the anterior limb of the right internal capsule
# 1	dsyn	C0333559	infarction, lacunar|lacunar, infarct
# normal morphology of the ventricular system
# with vp shunt with right parietal approach and distal tip in the volume of the right lateral ventricle
# the infratentorial compartment doesn't show abnormalities
# 1	cgab	C0000768	congenital abnormality|abnormalities
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# no evidence of intracranial acute bleed
# 0	patf	C0333276	acute hemorrhage|acute, bleed
# 0	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# bilateral holohemispheric chronic subdural hematomas with no interval remarkable change in comparison to previous study from september 11
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, hematomas
# no other interval remarkable variation
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old r / o subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	fndg	C0231337	senility|old, age
# comparison :
# previous brain mr from may 7
# 1	fndg	C4050513	minor response|mr
# 2016
# findings :
# normal morphology of the cerebral hemispheres
# cerebellum and brainstem
# no intracranial mass
# 0	fndg	C0270614	intracranial mass|intracranial, mass
# hemorrhage or hydrocepidural hematomaalus
# 1	patf	C0019080	hemorrhage|hemorrhage
# no midline shift
# no extra - axial collections
# no bony abnormalities
# 0	anab	C0410719	deformity of bone|bone, abnormalities
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# no evidence of intracranial bleed
# 0	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old
# severe headache
# 1	sosy	C2957106	headache severe|severe, headache
# known neoplasm
# 1	neop	C0027651	neoplasms|neoplasm
# 1	neop	C1882062	neoplastic disease|neoplasm
# previous ich
# 1	dsyn	C0019191	infectious canine hepatitis|ich
# 1	fndg	C3281105	hemorrhage, intracerebral, susceptibility to|ich
# r / o ich
# 1	dsyn	C0019191	infectious canine hepatitis|ich
# 1	fndg	C3281105	hemorrhage, intracerebral, susceptibility to|ich
# preliminary report performed by resident on call 19 : 40
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# multiple previous
# comparison to head ct from september 3 and brain mr from september 14
# 1	fndg	C4050513	minor response|mr
# findings :
# post surgical changes of left temporoparietal craniotomy for primary tumor resection
# 1	fndg	C0241311	post operative (finding)|post, surgery
# 1	neop	C0677930	primary tumor|primary, tumour
# with evidence of underlying encepidural hematomaalomalacic changes and hematoma with subacute blood products in the surgical cavity
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# 1	dsyn	C0011334	dental caries|cavity
# 1	anab	C1510420	cavitation|cavity
# measuring 44 x 52 mm
# with surrounding extensive vasogenic edema
# 1	fndg	C2825502	vasogenic edema|vasogenic, edema
# midline shift to the right measuring 10 mm and left descending transtentorial herniation with mass effect over the brainstem and contralateral lateral ventricle trapping
# 1	fndg	C3842590	10%|10
# 1	acab	C2937226	transtentorial hernia|transtentorial, herniation
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# interval significant increase in the vasogenic edema
# 1	fndg	C2825502	vasogenic edema|vasogenic, edema
# also in the midline shift to the right and left descending transtentorial herniation
# 1	acab	C2937226	transtentorial hernia|transtentorial, herniation
# recuring tumor with hemorrhagic transformation with expected evolution and no interval significant change [ in comparison to mr from september 14 ]
# 1	neop	C0027651	neoplasms|tumour
# 1	fndg	C3273930	tumor mass|tumor
# 1	patf	C1510411	metaplastic cell transformation|transformation
# 0	fndg	C4050513	minor response|mr
# right lateral ventricle trapping
# { e - signature }
# { e - signature }
# final report
# clinical information : 59m transfered from notre dame with right temporal lobe subdural + / - intracranial hemorrage ( initial ct 3 : 30 )
# 1	fndg	C3842588	30%|30
# { age _ number } years old
# preliminary report was on by resident on - call 0 : 41
# 1	fndg	C3842591	0%|0
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# no previous
# findings :
# right temporal acute parenchymal hematoma with volume of 17 cc and local mass effect
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# with mild extension to the posterior aspect of the right supraorbital frontal gyri
# cerebellar subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0149854	cerebellar hemorrhage|cerebellar, haemorrhage
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# patchy hypodensities involving the supratentorial periventricular white matter
# no midline shift
# left parietal subgaleal hematoma with no evidence of fracture
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 0	inpo	C0016658	fracture|fracture
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# left parietal subgaleal hematoma with no evidence of underlying fracture
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 0	inpo	C0016658	fracture|fracture
# right frontotemporal hemorrhagic contusions with right temporal acute parenchymal hematoma measuring 17 cc
# 1	inpo	C0009938	contusions|contusions
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# chronic microvascular white matter changes
# 1	fndg	C1833300	white matter changes|white, matter, changes
# { e - signature }
# { e - signature }
# final report
# clinical information : f / u subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# { age _ number } years old
# preliminary report was done by resident on call 21 : 15
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# previous head ct available from september 17
# findings :
# follow - up study with multi compartmental intracranial bleeds
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleeds
# with left holohemispheric acute subdural hematoma with predominant involvement of the superior surface of the left tentorial leaflet and of the left occipitoparietal region
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# also left parietal hemorrhagic contusions
# 1	inpo	C0009938	contusions|contusions
# subarachnoid hemorrhage with intraventricular extension
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# interval increase in the mass effect and contusions surrounding edema with secondary crowding of the subarachnoid spaces and partial compression of the posterior horn of the left lateral ventricle
# 1	inpo	C0009938	contusions|contusions
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	fndg	C0013604	edema|oedema
# 1	anab	C0040433	tooth crowding|crowding
# 1	neop	C0027627	neoplasm metastasis|secondary
# also mild midline shift to the right
# redemonstration of depression of the posterior edge of the left parietal craniotomy bone flap with overlying acute subgaleal hematoma
# 1	mobd	C0011570	mental depression|depression
# 1	mobd	C0011581	depressive disorder|depression
# 1	fndg	C0344315	depressed mood|depression
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# encepidural hematomaalomalacic changes involving the left parietal lobe and the left cerebellar hemisphere
# chronic microvascular white matter changes and age - related brain volume loss
# 1	fndg	C1833300	white matter changes|white, matter, changes
# 1	fndg	C0445223	related personal status|related
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multi compartmental intracranial traumatic bleed with no interval significant change for the left holohemispheric acute subdural hematoma
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# 0	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# subarachnoid hemorrhage and left temporal hemorrhagic contusions
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, haemorrhages
# 1	inpo	C0009938	contusions|contusions
# mild interval increase in the mass effect with secondary crowding of the subarachnoid spaces and partial compression of the posterior horn of the left lateral ventricle
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	anab	C0040433	tooth crowding|crowding
# 1	neop	C0027627	neoplasm metastasis|secondary
# no other remarkable interval change
# { e - signature }
# { e - signature }
# final report
# clinical information : blunt trauma
# 1	inpo	C0043253	nonpenetrating wounds|blunt, trauma
# { age _ number } years old
# preliminary report performed by resident on call 15 : 28
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# previous head ct available from march 14
# 2006
# ct head from lakeshore
# findings :
# left holohemispheric acute subdural hematoma involving the left leaflet of the cerebellar tentorium with interhemispheric occipitoparietal extension
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# with maximal thickness measuring 16 mm and mass effect over the underlying brain parenchyma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# hemorrhagic contusion involving the left parietal angular gyrus overlapping encepidural hematomaalomalacic changes
# 1	inpo	C0009938	contusions|contusion
# traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# with mild intraventricular extension
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# patchy hypodensities involving the supratentorial white matter
# asymmetric compression of the left lateral ventricle
# left parietal craniotomy with depression of the posterior age of the bone flap
# 1	mobd	C0011570	mental depression|depression
# 1	mobd	C0011581	depressive disorder|depression
# 1	fndg	C0344315	depressed mood|depression
# with overlying acute subgaleal hematoma
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# acute traumatic depression of the posterior edge of the bone flap of the left parietal craniotomy
# 1	mobd	C1386135	acute depression|acute, depression
# with overlying acute subgaleal hematoma
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# left holohemispheric acute subdural hematoma with predominant involvement of the surface of the tentorium
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left parietal hemorrhagic contusions involving the angular gyrus with associated encepidural hematomaalomalacic changes from a previous injury
# 1	inpo	C0009938	contusions|contusions
# 1	inpo	C3263722	traumatic and/or non-traumatic injury|injury
# 1	inpo	C3263723	traumatic injury|injury
# traumatic subarachnoid hemorrhage with intraventricular extension
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# chronic microvascular white matter changes
# 1	fndg	C1833300	white matter changes|white, matter, changes
# { e - signature }
# { e - signature }
# final report
# clinical information : followup for left small subarachnoid hemorrhage
# 1	fndg	C0589120	follow-up status|follow, up
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# comparison :
# previous head ct done at the jewish general hospital on september 16
# findings :
# right temporal hemorrhagic contusion involving the inferior temporal gyrus with overlying subarachnoid hemorrhage and small acute subdural hematoma with maximal thickness measuring 4 mm
# 1	inpo	C0009938	contusions|contusion
# 1	dsyn	C1399315	subarachnoid hematoma|subarachnoid, hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	fndg	C3842087	4 mm|4, mm
# left temporal acute subdural hematoma with maximal thickness measuring 6 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3842086	6 mm|6, mm
# overlying the left anterior temporal pole
# patchy hypodensities involving the periventricular and subcortical supratentorial white matter
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# the gray and white matter differentiation is preserved
# displaced fracture of the left zygomatic arch
# 1	inpo	C0585059	fracture with displacement|displaced, fracture
# nondisplaced fracture of the anterior portion of the squamous portion of the left temporal lobe with extension to the greater wing of the sphenoid
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# with lying the subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multi compartmental traumatic bleed with hemorrhagic contusions of the right inferior temporal gyrus
# 1	inpo	C0040797	traumatic hemorrhage|traumatic, bleeds
# 1	inpo	C0009938	contusions|contusions
# right temporal acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left temporal acute subdural hematoma and traumatic subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# displaced fracture of the left zygomatic arch and of the posterior lateral wall of the left maxillary sinus and nondisplaced fracture of the anterior aspect of the squamous portion of the left temporal bone with extension to the greater wing of the sphenoid
# 1	inpo	C0585059	fracture with displacement|displaced, fracture
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# line chronic microvascular white matter changes and age - related brain volume loss
# 1	fndg	C1833300	white matter changes|white, matter, changes
# 1	fndg	C0445223	related personal status|related
# { e - signature }
# { e - signature }
# final report
# clinical information : fall
# 1	fndg	C0085639	falls|fall
# r / o bleed
# 1	patf	C0019080	hemorrhage|bleeds
# r / o right orbit #
# { age _ number } years old
# preliminary report performed by resident on call 1 : 44
# 1	fndg	C3840630	residence 1|residence, 1
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# comparison :
# previous head ct available from july 16
# findings :
# patchy hypodensities involving the periventricular and subcortical supratentorial white matter
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# the gray and white matter differentiation is preserved
# normal morphology of the cerebral hemispheres
# cerebellum and brainstem
# focal intra - axial subarachnoid hyperdensity involving the left inferior frontal sulcus
# no ischemic lesions are detected
# 0	fndg	C0221198	lesion|lesions
# 0	fndg	C0442726	detected (finding)|detected
# no bony abnormalities
# 0	anab	C0410719	deformity of bone|bone, abnormalities
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# focal extra - axial subarachnoid hyperdensity involving the left inferior frontal sulcus
# most likely due to line of beam hardening artifact
# 1	fndg	C2828112	beam hardening artifact|beam, hardening, artifact
# however is not possible to completely rule out subarachnoid hemorrhage
# 0	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 6 hours follow - up head ct is recommended
# 1	fndg	C0589120	follow-up status|follow, up
# chronic microvascular white matter changes and age - related brain volume loss
# 1	fndg	C1833300	white matter changes|white, matter, changes
# 1	fndg	C0445223	related personal status|related
# { e - signature }
# { e - signature }
# final report
# clinical information : f79
# headache
# 1	sosy	C0018681	headache|headache
# lethargia
# episode of dysarthria with onset 9am
# 1	mobd	C0013362	dysarthria|dysarthria
# ro stroke
# 0	dsyn	C0038454	cerebrovascular accident|stroke
# preliminary report performed by resident on call 1 : 30
# 1	fndg	C3840630	residence 1|residence, 1
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3842588	30%|30
# comparison :
# previous head ct available from 2016 february 5
# findings :
# motion artifact limiting the proper assessment of the examination
# acute intra - axial right temporoparietal hematoma with volume of 28 cc
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# surrounded by mixed edema with mass effect and right mild uncal herniation and midline shift to the left measuring 4 mm
# 1	fndg	C0013604	edema|oedema
# 1	fndg	C3160715	mixed cell morphology|mixed
# 1	fndg	C0427514	right shifted white blood cells|right, shift
# 1	acab	C0393985	uncinate herniation|uncal, herniation
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	fndg	C3843236	measurement 4|measurement, 4
# partial compression of the right lateral ventricle
# small amount of subarachnoid hemorrhage in the right temporal sulci
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# secondary crowding of the right hemispheric subarachnoid spaces
# 1	neop	C0027627	neoplasm metastasis|secondary
# 1	anab	C0040433	tooth crowding|crowding
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# patchy hypodensities involving the periventricular supratentorial white matter
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# right temporoparietal acute parenchymal hematoma
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# most likely due to amyloid angiopathy with mild uncal herniation and midline shift to the left
# 1	dsyn	C2931784	amyloid angiopathy|amyloid, angiopathy
# 1	acab	C0393985	uncinate herniation|uncal, herniation
# associated subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# mild chronic microvascular white matter changes
# 1	fndg	C1833300	white matter changes|white, matter, changes
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# { e - signature }
# { e - signature }
# final report
# clinical information : blunt trauma
# 1	inpo	C0043253	nonpenetrating wounds|blunt, trauma
# { age _ number } years old
# preliminary report performed by resident on call 00 : 31
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# no previous head study available
# findings :
# traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# bilateral frontal and temporal hemorrhagic contusions involving the supra orbital gyri and the anterior temporal pole
# 1	inpo	C0009938	contusions|contusions
# bilateral frontotemporal acute subdural hematomas with frontotemporal predominance
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# crowding of the subarachnoid spaces and of the suprasellar cistern
# 1	anab	C0040433	tooth crowding|crowding
# and keeping with supratentorial intracranial hypertension
# 1	dsyn	C0151740	intracranial hypertension|intracranial, hypertension
# pneumocepidural hematomaalus with intravascular venous distribution involving the right transverse sinus and the superior sagittal sinus
# multiple displaced fractures involving the left parasagittal aspect of the occipital bone
# 1	inpo	C0585059	fracture with displacement|displaced, fractures
# 1	inpo	C0016655	fractures, multiple|multiple, fractures
# both lambdoid sutures with diastasis
# 1	patf	C0036679	diastasis|diastasis
# the left mastoid air cells with secondary opacification
# 1	neop	C0027627	neoplasm metastasis|secondary
# the walls of the left carotid canal
# the floor of the sella turcica and the posterior wall of the sphenoidal sinuses
# ct angiography of the head was performed
# only arterial phase of the head was achieved
# not venous
# normal opacification of the arterial structures with no evidence of dissection
# 1	fndg	C0231683	gait normal|normal
# 0	patf	C0333288	dissecting hemorrhage|dissection
# stenosis or thrombosis
# 1	patf	C0040053	thrombosis|thrombosis
# 1	patf	C2586211	thrombosis of blood vessel|thrombosis
# 1	patf	C1261287	stenosis|stenosis
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multi compartmental intracranial traumatic bleed with bilateral frontotemporal acute subdural hematomas
# 1	patf	C0151699	intracranial hemorrhages|intracranial, bleed
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# bifrontal and bitemporal hemorrhagic contusions
# 1	inpo	C0009938	contusions|contusions
# diffuse edema with early intracranial hypertension of the supratentorial compartment
# 1	fndg	C0013604	edema|oedema
# 1	dsyn	C0151740	intracranial hypertension|intracranial, hypertension
# multiple skull and calvarium fractures with left occipital parasagittal involvement
# 1	inpo	C0016658	fracture|fractures
# bilateral diastases of the lambdoid sutures
# left temporal bone extension and sella turcica floor with sphenoidal hemosinus
# pneumocepidural hematomaalus with apparent intravascular venous distribution
# traumatic venous sinus injury should be ruled out
# 0	inpo	C3263723	traumatic injury|traumatic, injury
# 0	inpo	C3714660	trauma|traumatic, injury
# no evidence of intracranial arterial traumatic vascular injury
# 0	inpo	C0178324	vascular system injuries|injury, of, blood, vessel
# ct venogram is required to rule out venous sinus traumatic injury and ct angiogram of the neck is suggested to complete the trauma protocol
# 0	inpo	C3263723	traumatic injury|traumatic, injury
# 0	inpo	C3714660	trauma|traumatic, injury
# 0	inpo	C0340770	injury of vein|venous, injury
# 0	anab	C0333336	traumatic fistula|traumatic, sinus
# 0	fndg	C0424012	suggestible|suggestible
# 0	fndg	C3715209	protocol - answer to question|protocol
# 0	inpo	C0043251	wounds and injuries|trauma
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old f / u tbi please do at noon ( 12 : 00pm )
# 1	inpo	C0876926	traumatic brain injury|tbi
# 1	fndg	C0231337	senility|old, age
# comparison :
# previous head ct available from the same day earlier
# findings :
# right frontal small subdural acute hematoma with maximal thickness measuring 3 mm
# 1	fndg	C1845250	small forehead|small, forehead
# 1	patf	C0749098	hematoma, subdural, acute|hematoma, subdural, acute
# 1	fndg	C3842088	3 mm|3, mm
# traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# hemorrhagic contusions involving the right temporal lobe
# 1	inpo	C0009938	contusions|contusions
# the right supraorbital frontal gyri
# no midline shift
# diffuse crowding of the right hemispheric subarachnoid spaces suggestive of diffuse edema
# 1	anab	C0040433	tooth crowding|crowding
# 1	fndg	C0013604	edema|oedema
# redemonstration of skull fractures
# 1	inpo	C0016658	fracture|fractures
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# follow - up study with mild interval increase in the hemorrhagic contusions edema
# 1	inpo	C0009938	contusions|contusions
# 1	fndg	C0013604	edema|oedema
# interval stability in the right frontal acute subdural hematoma and in the distribution of the subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# mild diffuse edema involving the right cerebellar hemisphere
# 1	fndg	C0013604	edema|oedema
# most evident on the right frontoparietal convexity
# { e - signature }
# { e - signature }
# final report
# clinical information : 22m loc r / o acute head injury
# 1	inpo	C0018674	craniocerebral trauma|head, injury
# 1	fndg	C0234425	level of consciousness|loc
# comparison :
# no previous
# findings :
# there is a fracture involving the lateral aspect of the left temporal bone
# 1	inpo	C0016658	fracture|fracture
# probably entering the middle ear cavity
# 1	dsyn	C0011334	dental caries|cavity
# 1	anab	C1510420	cavitation|cavity
# there is a small amount of soft tissue or blood in the middle ear cavity
# 1	dsyn	C3542022	short stature, onychodysplasia, facial dysmorphism, and hypotrichosis syndrome|soft
# 1	dsyn	C0011334	dental caries|cavity
# 1	anab	C1510420	cavitation|cavity
# therefore a ct temporal bones is recommended for further evaluation
# nondisplaced fracture of the squamous portion of the left temporal bone
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# images the brain demonstrate evidence for hemorrhage in the cortex of the right frontal lobe anteriorly
# 1	patf	C0019080	hemorrhage|hemorrhage
# the right temporal operculum
# and the lateral aspect of the right temporal lobe
# these are likely a combination of contusion and subarachnoid hemorrhage
# 1	fndg	C3811910	combination - answer to question|combination
# 1	inpo	C0009938	contusions|contusion
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# the subarachnoid spaces are effaced diffusely
# but this is probably due to young age of the patient rather than brain edema
# 0	patf	C0006114	cerebral edema|brain, oedema
# 0	patf	C1527311	brain edema|brain, oedema
# if the patient is very impaired
# brain edema should be considered
# 1	patf	C0006114	cerebral edema|brain, oedema
# 1	patf	C1527311	brain edema|brain, oedema
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multiple areas of traumatic brain injury
# 1	inpo	C0876926	traumatic brain injury|traumatic, brain, injury
# including right frontal
# right temporal contusions and subarachnoid hemorrhage
# 1	inpo	C0009938	contusions|contusions
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# left temporal bone fractures ; involving the tympanic portion and squamous portion
# 1	inpo	C0016658	fracture|fractures
# 1	fndg	C0577946	chest tympanitic to percussion|tympany
# close term follow - up is recommended to evaluate for brain swelling
# 1	fndg	C3810854	close|close
# 1	fndg	C0589120	follow-up status|follow, up
# 0	patf	C1527311	brain edema|brain, swelling
# follow up scan at 6 to 12 hours is recommended
# 1	fndg	C0589120	follow-up status|follow, up
# 1	fndg	C2826292	related to cancer|scan
# left parietal subgaleal swelling
# 1	fndg	C0013604	edema|swelling
# 1	fndg	C0038999	swelling|swelling
# { e - signature }
# final report
# clinical information : controle subdural hematoma at 19h00
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# comparison :
# no outside images are presently available for comparison
# the study from the jg h is not on the muhc pacs
# findings :
# the on - call residents were concerned for a potential small subdural collection along the interhemispheric falx cerebri
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# i do appreciate a very focal minimal thickening along the falx
# 1	fndg	C0205400	thickened|thickening
# but this could simply be a normal variant
# 1	fndg	C0544712	normal variation|normal, variant
# alternatively
# a very small amount of subdural or subarachnoid blood along the falx is possible
# elsewhere
# no other significant intracranial abnormalities are detected
# 0	cgab	C0000768	congenital abnormality|abnormalities
# 0	fndg	C0442726	detected (finding)|detected
# left zygomatic arch fracture
# 1	inpo	C0435332	fracture of zygomatic process|zygomatic, arch, fracture
# 1	inpo	C0016658	fracture|fracture
# facial bone ct dictated separately
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# a definite subdural hematoma along the falx is not identified
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 0	fndg	C1550043	container status - identified|identified
# although a small amount of blood is possible
# no significant abnormalities otherwise within the brain
# 0	cgab	C0000768	congenital abnormality|abnormalities
# left zygomatic arch fracture
# 1	inpo	C0435332	fracture of zygomatic process|zygomatic, arch, fracture
# 1	inpo	C0016658	fracture|fracture
# { e - signature }
# final report
# clinical information : head trauma at 1 am please
# 1	fndg	C3842784	injury 1|trauma, 1
# { age _ number } years old
# preliminary report performed by resident on call 2 : 22
# 1	fndg	C3843912	residence 2|residence, 2
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# comparison :
# previous head ct from the same day earlier
# findings :
# right frontal supraorbital mild hemorrhagic contusions overlying the comminuted fracture of the right orbital roof
# 1	inpo	C0009938	contusions|contusions
# 1	inpo	C0476171	comminuted fracture type|comminuted, fracture
# right frontal subdural pneumocepidural hematomaalus
# midline retroclival acute subdural hematoma with maximal thickness measuring 3
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	fndg	C3838680	3+ answer to question|3
# 8 mm
# left frontal small subdural hematoma with maximal thickness measuring 4 mm
# 1	fndg	C1845250	small forehead|small, forehead
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 1	fndg	C3842087	4 mm|4, mm
# small amount of subarachnoid hemorrhage involving the interpeduncular cistern
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# redemonstration of multiple skull
# skull base and facial bones fractures
# 1	inpo	C0016658	fracture|fractures
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# follow - up study with no significant interval change
# with redemonstration of right frontal supraorbital small hemorrhagic contusions
# 1	fndg	C1845250	small forehead|small, forehead
# 1	inpo	C0009938	contusions|contusions
# subdural pneumocepidural hematomaalus
# retroclival acute subdural hematoma
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# left frontal acute subdural hematoma and small amount of traumatic subarachnoid hemorrhage
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematoma
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old fall from bed
# 1	fndg	C0085639	falls|fall
# 1	fndg	C0231337	senility|old, age
# recent subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# preliminary report performed by resident on call 20 : 21
# 1	fndg	C3842589	20%|20
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# comparison :
# comparison to head ct from august 30
# 1	fndg	C3842588	30%|30
# 2017
# findings :
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# patchy hypodensities involving the supratentorial white matter
# no midline shift
# calcification of the falx cerebri
# 1	patf	C0006663	calcinosis|calcification
# 1	fndg	C2242558	pathologic calcification, calcified structure|calcification
# atherosclerotic changes of the intracranial arteries
# the right temporoparietal small subdural hematoma is now isodense
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# interval resolution of the subarachnoid hemorrhage
# 1	patf	C1514893	physiologic resolution|resolution
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# no bony abnormalities
# 0	anab	C0410719	deformity of bone|bone, abnormalities
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# follow - up study with interval resolution of the subarachnoid hemorrhage and expected evolution of the right temporoparietal subdural hematoma
# 1	patf	C1514893	physiologic resolution|resolution
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# age - related brain volume loss
# 1	fndg	C0445223	related personal status|related
# chronic microvascular white matter changes
# ...
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C3840882	5 mm|5, mm
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# subarachnoid hemorrhage in the left frontal parasagittal spaces
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# ventricular shunt with the described location
# left frontoparietal chronic subdural hematoma with acute rebleeding and mild mass effect
# 1	patf	C0749095	hematoma, subdural, chronic|chronic, subdural, haematoma
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# left parasagittal frontal subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# age - related brain volume loss and chronic microvascular white matter changes
# 1	fndg	C1833300	white matter changes|white, matter, changes
# 1	fndg	C0445223	related personal status|related
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } years old blunt trauma
# 1	inpo	C0043253	nonpenetrating wounds|blunt, trauma
# 1	inpo	C0332666	old injury|old, trauma
# 1	fndg	C0231337	senility|old, age
# comparison :
# no previous
# findings :
# extensive subarachnoid hemorrhage with intraventricular hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0240059	ventricular hemorrhage|intraventricular, haemorrhage
# bilateral holohemispheric acute subdural hematomas with maximal thickness on the left of 6 mm and on the right of 4 mm
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# 1	fndg	C3842086	6 mm|6, mm
# 1	fndg	C3842087	4 mm|4, mm
# with secondary balanced mass effect
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# 1	neop	C0027627	neoplasm metastasis|secondary
# acute hemorrhagic foci involving the corpus callosum and the left midbrain and hypothalamic region
# 1	patf	C0333276	acute hemorrhage|acute, hemorrhage
# bilateral frontal hemorrhagic contusions
# 1	inpo	C0009938	contusions|contusions
# postsurgical changes of right frontal craniotomy with underlying right frontal encepidural hematomaalomalacia filled with acute hematoma
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# nondisplaced fracture of the right frontal bone extending to the anterior and posterior wall of the frontal sinus
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# please refer to the report of the ct facial bones for description of the fractures
# 1	inpo	C0016658	fracture|fractures
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# extensive subarachnoid hemorrhage with intraventricular hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# 1	patf	C0240059	ventricular hemorrhage|intraventricular, haemorrhage
# hemorrhagic foci in the corpus callosum and left cerebral peduncle suggestive of diffuse axonal injury
# 1	inpo	C0752219	diffuse axonal injury|diffuse, axonal, injury
# bilateral holohemispheric acute subdural hematomas
# 1	patf	C0749098	hematoma, subdural, acute|acute, subdural, hematomas
# bifrontal acute hemorrhagic brain contusions
# 1	inpo	C0149844	brain contusion|brain, contusions
# postsurgical changes in the right frontal lobe with area of encepidural hematomaalomalacia filled with an hematoma
# 1	patf	C0018944	hematoma|hematoma
# 1	fndg	C1962958	hematoma adverse event|hematoma
# fracture of the right frontal bone
# 1	inpo	C0016658	fracture|fracture
# please refer to the report of the ct facial bones for description of the fractures
# 1	inpo	C0016658	fracture|fractures
# ct angiogram of the head and of the neck is strongly recommended
# preliminary report was done by resident on call
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } year - old { gender } trauma
# 1	inpo	C0332666	old injury|old, trauma
# comparison :
# ct head of the the same date performed at 4 : 45 pm at an outside institution
# 1	fndg	C3838679	4+ answer to question|4
# 1	fndg	C4049155	infusion pump alert priority pm|pm
# findings :
# interval mild increase in the size of the inferior frontal lobes parenchymal contusions with stable surrounding vasogenic edema and mass effect with overlying sulcal effacement
# 1	inpo	C0009938	contusions|contusions
# 1	fndg	C2825502	vasogenic edema|vasogenic, edema
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# left sided subdural hematoma has redistributed now being holohemispheric
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# it measures up to 1
# 1 cm over the frontal lobe
# 1	fndg	C3816745	1+|1
# thin right frontal
# interhemispheric thin bilateral tentorial subdural hematomas
# 1	patf	C0018946	hematoma, subdural|subdural, hematomas
# scattered subarachnoid hemorrhage along the interhemispheric fissure
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# suprasellar cistern
# interpeduncular fossa and over the cerebral convexities similar to previous
# no acute cerebral infarct
# 0	dsyn	C2215101	acute cerebral hypoperfusion|acute, cerebral, infarct
# the frontal contusions cause mild mass effect on the frontal horns of the lateral ventricles
# 1	inpo	C0009938	contusions|contusions
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# no midline shift
# small amount of hemorrhage layering in the occipital horns of the lateral ventricles
# 1	patf	C0019080	hemorrhage|hemorrhage
# no hydrocepidural hematomaalus
# nondisplaced fracture of the frontal bone on the right
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# old fractures of the right orbital floor
# 1	inpo	C0016658	fracture|fractures
# lateral wall and lamina papyracea with mesh reconstruction along the orbital floor
# right ocular scleral band in place
# previous repair of a fracture at the anterior wall of the left maxillary sinus
# 1	inpo	C0016658	fracture|fracture
# tortuous and distended optic nerve sheath complexes raising concern for increased intracranial pressure
# 1	fndg	C4068863	tortuous|tortuous
# 1	fndg	C0700124	dilated|distended
# 1	dsyn	C0151740	intracranial hypertension|increased, intracranial, pressure
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multicompartmental post - traumatic intracranial hemorrhages showing mild interval enlargement
# 1	inpo	C0273058	traumatic intracranial hemorrhage|traumatic, intracranial, hemorrhages
# 1	patf	C0020564	hypertrophy|enlargement
# 1	anab	C2711450	enlargement (morphologic abnormality)|enlargement
# tortuous and distended optic nerve sheath complexes raising concern for increased intracranial pressure
# 1	fndg	C4068863	tortuous|tortuous
# 1	fndg	C0700124	dilated|distended
# 1	dsyn	C0151740	intracranial hypertension|increased, intracranial, pressure
# acute nondisplaced fracture of the frontal bone on the right
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# close follow - up is recommended
# 1	fndg	C3810854	close|close
# 1	fndg	C0589120	follow-up status|follow, up
# a concordant preliminary report was given by the resident on - call on july 19
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 2017 at 11 : 33 pm
# { e - signature }
# final report
# clinical indications : { age _ number } years old trauma
# 1	inpo	C0332666	old injury|old, trauma
# multiple falls
# 1	inpo	C0000921	accidental falls|falls
# 1	fndg	C0085639	falls|falls
# preliminary report was on by resident on call
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# previous :
# no previous head studies
# findings :
# intraventricular hemorrhage in the occipital horn of the right lateral ventricle
# 1	patf	C0240059	ventricular hemorrhage|intraventricular, haemorrhage
# focal hyperdensity involving the gray and white matter of the right frontal gyrus
# no midline shift
# the brainstem and the cerebellum are normal
# 1	fndg	C0231683	gait normal|normal
# displaced fracture of anterior and posterior arches of c1
# 1	inpo	C0585059	fracture with displacement|displaced, fracture
# 1	fndg	C0456879	tnm certainty factor c1|c1
# ct angiogram of the head and of the neck was performed
# atherosclerotic changes of the articular arch and of the carotid bulbs with no secondary stenosis
# 0	patf	C1261287	stenosis|stenosis
# 0	neop	C0027627	neoplasm metastasis|secondary
# displaced is of anterior and posterior arches of c1 with corticated margins suggestive of chronic evolution with subluxation of the atlantoaxial joint
# 1	fndg	C0456879	tnm certainty factor c1|c1
# 1	fndg	C1550517	target awareness - marginal|marginal
# 1	inpo	C0332768	subluxation of joint|subluxation
# no evidence of stenosis or thrombosis or dissection
# 0	patf	C0333288	dissecting hemorrhage|dissection
# 0	patf	C0040053	thrombosis|thrombosis
# 0	patf	C1261287	stenosis|stenosis
# 0	patf	C2586211	thrombosis of blood vessel|thrombosis
# intraorbital bilateral extraconal masses that require additional evaluation
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# acute intraventricular hemorrhage in the occipital horn of the right lateral ventricle
# 1	patf	C0240059	ventricular hemorrhage|intraventricular, haemorrhage
# 1	patf	C0333276	acute hemorrhage|acute, hemorrhage
# associated subarachnoid hemorrhage should be considered
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# but is not evident in the current study
# acute hemorrhagic contusion involving the right superior frontal gyrus
# 1	patf	C0333276	acute hemorrhage|acute, hemorrhage
# 1	inpo	C0009938	contusions|contusion
# c1 fracture better described in the cervical spine ct
# 1	fndg	C0456879	tnm certainty factor c1|c1
# 1	inpo	C0016658	fracture|fracture
# with associated subluxation of atlantoaxial joint
# 1	inpo	C0332768	subluxation of joint|subluxation
# that may be chronic
# no evidence of acute traumatic vascular injury
# 0	inpo	C0178324	vascular system injuries|injury, of, blood, vessel
# right frontal subgaleal hematoma
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# intraorbital bilateral extraconal masses that require additional evaluation
# { e - signature }
# { e - signature }
# final report
# clinical information : intubated trauma tansfer motorcycle collision
# 1	inpo	C0337196	collision|collision
# 1	inpo	C0043251	wounds and injuries|trauma
# 1	inpo	C3263723	traumatic injury|trauma
# 1	inpo	C3714660	trauma|trauma
# { age _ number } years old
# comparison :
# no previous head studies
# findings :
# scattered small amount of subarachnoid hemorrhage in the interpeduncular cistern and within sulci over the left temporal
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# frontal and parietal lobes
# the gray and white matter differentiation is preserved
# no midline shift
# the ventricular system has normal size
# right frontal soft tissue swelling and subgaleal hematoma with emphysema
# 1	dsyn	C0037580	soft tissue swelling|soft, tissue, swelling
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 1	patf	C0013990	pathological accumulation of air in tissues|emphysema
# 1	dsyn	C0034067	pulmonary emphysema|emphysema
# partial opacification of the paranasal sinuses likely related to the intubation
# 1	fndg	C0445223	related personal status|related
# nondisplaced fracture of the right temporal bone involving the floor of the middle cranial fossa with posterior extension to the temporomandibular fossa and mastoid cells
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# nondisplaced fracture of the anterior wall of the right frontal sinus
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# small effusion in the right mastoid air cells
# 1	patf	C0013687	effusion|effusion
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# small amount of traumatic subarachnoid hemorrhage
# 1	inpo	C0475073	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# nondisplaced fracture of the right temporal bone involving the floor of the middle cranial fossa extending to the temporomandibular fossa and mastoid air cells and nondisplaced fracture of the anterior wall of the right frontal sinus
# 1	inpo	C0585058	undisplaced fracture|non, displaced, fracture
# preliminary report was done by resident on call 4 : 04
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3835651	resident - answer to question|resident
# { e - signature }
# { e - signature }
# final report
# clinical information : { age _ number } year - old { gender } intraparenchymal bleed
# 1	patf	C0019080	hemorrhage|bleed
# 1	fndg	C0231337	senility|old, age
# subdural hematoma
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# subarachnoid hemorrhage
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# progressing on last ct
# control please
# comparison :
# previous of the same date performed at an outside institution
# findings :
# moderate - sized hemorrhagic parenchymal contusions in the right inferior frontal and right anterior temporal lobes with mildly increased surrounding edema
# 1	patf	C0747264	parenchymal hemorrhage|parenchymal, hemorrhage
# 1	inpo	C0009938	contusions|contusions
# 1	fndg	C0013604	edema|oedema
# mild regional mass effect with effacement of the overlying sulci
# 1	fndg	C0577559	mass of body structure|mass
# 1	sosy	C0577573	mass of body region|mass
# no midline shift
# thin right posterior parafalcine subdural hematoma without significant mass effect
# 1	patf	C0018946	hematoma, subdural|subdural, haematoma
# 0	fndg	C0577559	mass of body structure|mass
# 0	sosy	C0577573	mass of body region|mass
# small amount of scattered subarachnoid hemorrhage which has redistributed over the parietal lobes
# 1	dsyn	C0038525	subarachnoid hemorrhage|subarachnoid, hemorrhage
# right more than left and within the parasagittal sulci at the vertex
# the gray - white matter differentiation is preserved
# mild generalized age - related cerebral and cerebellar atrophy
# 1	fndg	C3809846	cerebral atrophy, generalized mild|generalized, mild, cerebral, atrophy
# 1	fndg	C0445223	related personal status|related
# the ventricular systems within normal limits
# the basal cisterns are patent
# moderately large subgaleal hematoma over the parietal bones and a small subcutaneous hematoma over the right posterior parietal bone
# 1	inpo	C2721649	subgaleal hematoma|subgaleal, hematoma
# 1	acab	C0520532	subcutaneous hematoma|subcutaneous, haematoma
# no depressed calvarial fracture
# 0	inpo	C0332759	depressed fracture|depressed, fracture
# moderate mucosal thickening in the left sphenoid sinus
# 1	fndg	C3686502	mucosal thickening|mucosal, thickening
# the orbits and nasopharyngeal region are unremarkable
# impression :
# 1	fndg	C4049863	radiologic impression|impression
# multicompartmental posttraumatic intracranial hemorrhages with mildly increased edema surrounding the hemorrhagic parenchymal contusions
# 1	patf	C0151699	intracranial hemorrhages|intracranial, hemorrhages
# 1	fndg	C0013604	edema|oedema
# 1	patf	C0747264	parenchymal hemorrhage|parenchymal, hemorrhage
# 1	inpo	C0009938	contusions|contusions
# a concordant preliminary report was given by the resident on - call on july 17
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 2017 at 11 : 18 pm
# 1	fndg	C4049155	infusion pump alert priority pm|pm
# { e - signature }
# final report
# clinical information : { age _ number } year - old man f / u subarachnoid
# 1	fndg	C0231337	senility|old, age
# to do at / after 0930 please
# comparison : ct done 6 hours earlier
# preliminary report given by radiology resident on - call at 10 : 30 hours
# 1	fndg	C3835651	resident - answer to question|resident
# 1	neop	C1292769	precursor b-cell lymphoblastic leukemia|c, all
# 1	fndg	C3842590	10%|10
# 1	fndg	C3842588	30%|30
# findings : multiple hemorrhagic foci remain fairly stable
# the right sylvian fissure bleed seems slightly longer
# 1	patf	C0019080	hemorrhage|bleed
# this may be redistribution
# { e - signature }

# %%
dtt[:1]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rpr  \
# 0  final report . clinical information : { age _ number } year - old man trauma . comparison : no previous . preliminary report given by radiology resident on - call at 12 : 46 hours . findings : the patient is intubated and with an orogastric tube in place . acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities . maximum thickness of space collection is 0.9 cm . bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri . left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed . complex fracture of the right mastoid bone involving the middle ear . for better assessment . refer to ct facial bones . adjacent pneumocephalus adjacent to right transverse sinus . presence of tiny air pockets adjacent to the right orbital roof . suspicious for nondisplaced fracture along the orbital roof . impression : multi compartmental acute posttraumatic intracranial bleeds . right temporal bone complex fractures . { e - signature }
#
#    ttl  eph  sdh  iph  cnt  sah  ivh  sgh  mtm_sdh  \
# 0  4    0    1    1    1    1    0    0    1
#
#                                                                                                                    dsrs
# 0  C0333276 C0332666 C3835651 C0559567 C0038525 C0585058 C0749098 C4050405 C0151699 C3842591 C1292769 C4049863 C0016658

# %%
tmp = dtt[['rpr', 'dsrs', 'ttl', 'eph', 'sdh', 'iph', 'cnt', 'sah', 'ivh', 'sgh']]
tmp.to_csv('mtm.csv', encoding='latin-1', index=False, quoting=csv.QUOTE_NONNUMERIC)
dtt = pandas.read_csv('mtm.csv', delimiter=',', encoding='latin-1')
dtt[:1]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rpr  \
# 0  final report . clinical information : { age _ number } year - old man trauma . comparison : no previous . preliminary report given by radiology resident on - call at 12 : 46 hours . findings : the patient is intubated and with an orogastric tube in place . acute left convexity subdural hematoma extending from the anterior midline over the frontal temporal and parietal convexities . maximum thickness of space collection is 0.9 cm . bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri . left superior frontal acute subarachnoid hemorrhage . left inferior parietal small subarachnoid / intraparenchymal bleed . complex fracture of the right mastoid bone involving the middle ear . for better assessment . refer to ct facial bones . adjacent pneumocephalus adjacent to right transverse sinus . presence of tiny air pockets adjacent to the right orbital roof . suspicious for nondisplaced fracture along the orbital roof . impression : multi compartmental acute posttraumatic intracranial bleeds . right temporal bone complex fractures . { e - signature }
#
#                                                                                                                    dsrs  \
# 0  C0333276 C0332666 C3835651 C0559567 C0038525 C0585058 C0749098 C4050405 C0151699 C3842591 C1292769 C4049863 C0016658
#
#    ttl  eph  sdh  iph  cnt  sah  ivh  sgh
# 0  4    0    1    1    1    1    0    0

# %%
dsrs = ['epidural hematoma', 'subdural hematoma', 'intraparenchymal hemorrhage', 'contusion', 'subarachnoid hemorrhage', 'intraventricular hemorrhage', 'subgaleal hematoma']
dsrs
# Out:
# ['epidural hematoma',
#  'subdural hematoma',
#  'intraparenchymal hemorrhage',
#  'contusion',
#  'subarachnoid hemorrhage',
#  'intraventricular hemorrhage',
#  'subgaleal hematoma']

# %%
cui_lsts = [[] for i in range(7)]

# %%
for i in range(len(dsrs)):
    print(dsrs[i])
    cui_lsts[i] = rcm(dsrs[i])
    print()
# Out:
# epidural hematoma
# C0238154	1000	hematoma, epidural, cranial|epidural, haematoma
# C0877172	1000	hematoma, epidural, spinal|epidural, haematoma
# C2832464	960	epidural hemorrhage with loss of consciousness of unspecified duration|epidural, hemorrhage, with, loss, of, consciousness, of, unspecified, duration
# C0018944	960	hematoma|hematoma
# C1962958	960	hematoma adverse event|hematoma
# C4021393	951	spinalarachnoid cyst|epidural, arachnoid, cysts, of, the, spinal, canal
# C2832428	945	epidural hemorrhage without loss of consciousness|epidural, hemorrhage, without, loss, of, consciousness
# C0016428	933	eruption cyst|eruption, hematoma
# C0018946	933	hematoma, subdural|subdural, haematoma
# C0021870	933	intracerebral hematoma|intracerebral, haematoma
# C0021893	933	intraplacental hematoma|intraplacental, hematoma
# C0155784	933	thrombosed external hemorrhoids|perianal, hematoma
# C0156389	933	vaginal hematoma|vaginal, hematoma
# C0156397	933	vulval hematoma|vulval, hematoma
# C0240159	933	laryngeal hematoma|laryngeal, hematoma
# C0240412	933	muscle hematoma|muscle, haematoma
# C0267767	933	mesenteric hematoma|mesenteric, hematoma
# C0271413	933	hematoma of pinna|auricular, hematoma
# C0281860	933	wound hematoma|wound, hematoma
# C0302497	933	retrobulbar hemorrhage|retrobulbar, hematoma
# C0333198	933	organizing hematoma|organizing, haematoma
# C0333199	933	calcified hematoma|calcified, hematoma
# C0333200	933	intramural hematoma|intrinsic, hematoma
# C0338380	933	postoperative hematoma|postoperative, hematoma
# C0340161	933	hematomediastinum|mediastinal, hematoma
# C0341512	933	retroperitoneal hematoma|retroperitoneal, hematoma
# C0347630	933	liver hematoma|hepatic, hematoma
# C0347634	933	splenic hematoma|spleen, hematoma
# C0347659	933	hemorrhage into ovary|ovarian, hematoma
# C0392384	933	cerebellar hematoma|cerebellar, haematoma
# C0432742	933	superficial bruising|superficial, hematoma
# C0434104	933	rectal hematoma|rectal, hematoma
# C0473120	933	intra-abdominal hematoma|abdominal, hematoma
# C0473122	933	intraperitoneal hematoma|intraperitoneal, hematoma
# C0473123	933	omental hematoma|omental, hematoma
# C0473124	933	perinephric hematoma|perirenal, hematoma
# C0473220	933	intrarenal hematoma|intrarenal, hematoma
# C0473391	933	retroplacental hematoma|retroplacental, haematoma
# C0473491	933	perineal hematoma|perineal, hematoma
# C0474975	933	subungual hematoma|subungual, hematoma
# C0474976	933	deep hematoma|deep, hematoma
# C0475002	933	esophageal hematoma|oesophageal, haematoma
# C0475006	933	intrahepatic hematoma|intrahepatic, hematoma
# C0475011	933	peripancreatic hematoma|peripancreatic, hematoma
# C0475013	933	duodenal hematoma|duodenal, hematoma
# C0475015	933	appendix hematoma|appendix, hematoma
# C0475017	933	cecal hematoma|cecal, hematoma
# C0475021	933	colonic hematoma|colonic, hematoma
# C0475022	933	hematoma of kidney|renal, hematoma
# C0475319	933	pelvic hematoma|pelvic, hematoma
# C0520532	933	subcutaneous hematoma|subcutaneous, haematoma
# C0520723	933	periorbital hematoma|periorbital, hematoma
# C0542007	933	cerebral hematoma|cerebral, hematoma
# C0549453	933	traumatic hematoma|traumatic, haematoma
# C0554597	933	intermuscular hematoma|intermuscular, hematoma
# C0555306	933	gallbladder hematoma|gallbladder, hematoma
# C0559359	933	subchondral hematoma|subchondral, hematoma
# C0561797	933	hematoma of testis|testicular, hematoma
# C0561814	933	hematoma of uterus|uterus, hematoma
# C0585123	933	occipital haematoma|occipital, hematoma
# C0585249	933	hematoma of groin|inguinal, hematoma
# C0585250	933	hematoma of thigh|thigh, hematoma
# C0596793	933	intracranial hematoma|intracranial, hematoma
# C0741830	933	buttock hematoma|buttocks, hematoma
# C0744734	933	infected hematoma|infected, hematoma
# C0746795	933	hematoma of neck|neck, hematoma
# C0856150	933	spinal hematoma|spinal, hematoma
# C1096647	933	hematoma of lung|pulmonary, hematoma
# C1274053	933	subperiosteal hematoma|subperiosteal, hematoma
# C1385257	933	hematoma of face|facial, hematoma
# C1399315	933	subarachnoid hematoma|subarachnoid, hematoma
# C1510412	933	pseudoaneurysm|pulsating, hematoma
# C1536705	933	ovarian hematoma|ovarian, hematoma
# C1560580	933	ctcae grade 5 hematoma|fatal, hematoma
# C1956234	933	putaminal hematoma|putaminal, hematoma
# C2721649	933	subgaleal hematoma|subgaleal, hematoma
# C2747801	933	sinus hematoma|sinuses, hematoma
# C2747867	933	bowel haematoma|bowel, hematoma
# C2937358	933	cerebral hemorrhage|intracerebral, hematoma
# C3163669	933	neuraxial hematoma|neuraxial, hematoma
# C3472235	933	nontraumatic hematoma|nontraumatic, hematoma
# C3495808	933	subchorionic hematoma|subchorionic, haematoma
# C3670170	933	ethmoid hematoma|ethmoid, hematoma
# C3897450	933	subcapsular renal hematoma|subcapsular, hematoma
# C0270815	928	epidural ascending spinal paralysis|epidural, ascending, spinal, paralysis
# C0393491	928	epidural supratentorial pyogenic abscess|epidural, supratentorial, pyogenic, abscess
# C0393492	928	extradural infratentorial pyogenic abscess|epidural, infratentorial, pyogenic, abscess
# C1333416	928	epidural spinal canal angiolipoma|epidural, spinal, canal, angiolipoma
# C1333417	928	epidural spinal canal meningioma|epidural, spinal, canal, meningioma
# C0472385	925	nontraumatic epidural haematoma|nontraumatic, epidural, hematoma
# C0474997	925	traumatic spinal epidural hematoma|traumatic, epidural, hematoma
# C0475046	925	traumatic extradural hematoma|traumatic, epidural, hematoma
# C0475047	925	traumatic intracranial extradural hematoma|traumatic, epidural, hematoma
# C2062695	925	acute cranial epidural hematoma|acute, epidural, hematoma
#
# subdural hematoma
# C0018946	1000	hematoma, subdural|subdural, haematoma
# C0475059	1000	subdural hematoma, traumatic|subdural, traumatic, hematoma
# C0270085	945	subdural hemorrhage in fetus or newborn|subdural, hemorrhage, in, fetus, or, newborn
# C0018944	945	hematoma|hematoma
# C1962958	945	hematoma adverse event|hematoma
# C0473821	945	subdural hemorrhage due to birth trauma|subdural, hemorrhage, due, to, birth, trauma
# C2832504	943	traumatic subdural hemorrhage with loss of consciousness of unspecified duration|traumatic, subdural, hemorrhage, with, loss, of, consciousness, of, unspecified, duration
# C0393494	928	subdural supratentorial pyogenic abscess|subdural, supratentorial, pyogenic, abscess
# C0393495	928	subdural infratentorial pyogenic abscess|subdural, infratentorial, pyogenic, abscess
# C0238156	925	hematoma, subdural, intracranial|intracranial, subdural, hematoma
# C0475060	925	intracranial subdural hematoma, traumatic|traumatic, subdural, hematoma
# C0542322	925	subdural hematoma, nontraumatic|nontraumatic, subdural, hematoma
# C0749095	925	hematoma, subdural, chronic|chronic, subdural, haematoma
# C0749098	925	hematoma, subdural, acute|acute, subdural, hematoma
# C0751194	925	hematoma, subdural, spinal|spinal, subdural, haematoma
# C0854700	925	neonatal subdural haemorrhage|neonatal, subdural, hematoma
# C1997213	925	occipital subdural hematoma|occipital, subdural, hematoma
#
# intraparenchymal hemorrhage
# C3552968	944	intraparenchymal brain hemorrhage, multifocal|multifocal, intraparenchymal, brain, hemorrhage
# C3698285	944	nontraumatic intraparenchymal cerebral hemorrhage|spontaneous, intraparenchymal, cerebral, hemorrhage
# C0475010	928	intraparenchymal hematoma of spleen|intraparenchymal, hematoma, of, spleen
# C0019080	928	hemorrhage|hemorrhage
# C2316496	928	intraparenchymal hematoma of brain|intraparenchymal, hematoma, of, brain
#
# contusion
# C0009938	1000	contusions|contusion
#
# subarachnoid hemorrhage
# C0038525	1000	subarachnoid hemorrhage|subarachnoid, hemorrhage
# C4039573	944	nontraumatic subarachnoid intracranial hemorrhage|nontraumatic, subarachnoid, intracranial, hemorrhage
# C0270192	925	perinatal subarachnoid hemorrhage|perinatal, subarachnoid, haemorrhage
# C0472383	925	subarachnoid hemorrhage, spontaneous|spontaneous, subarachnoid, hemorrhage
# C0475073	925	subarachnoid hemorrhage, traumatic|traumatic, subarachnoid, haemorrhage
# C0751530	925	subarachnoid hemorrhage, aneurysmal|aneurysmal, subarachnoid, hemorrhage
# C0795688	925	subarachnoid hemorrhage, intracranial|intracranial, subarachnoid, hemorrhage
# C1410400	925	nontraumatic subarachnoid hemorrhage, unspecified|nontraumatic, subarachnoid, hemorrhage
# C3838874	925	perimesencephalic subarachnoid hemorrhage|perimesencephalic, subarachnoid, hemorrhage
# C3839590	925	convexal subarachnoid hemorrhage|convexal, subarachnoid, hemorrhage
#
# intraventricular hemorrhage
# C0240059	1000	ventricular hemorrhage|intraventricular, haemorrhage
# C0475526	1000	intracerebral hemorrhage, intraventricular|intraventricular, intracerebral, hemorrhage
# C2882321	1000	nontraumatic intracerebral hemorrhage, intraventricular|intraventricular, nontraumatic, intracerebral, hemorrhage
# C0270191	925	perinatal intraventricular hemorrhage|perinatal, intraventricular, haemorrhage
#
# subgaleal hematoma
# C2721649	1000	subgaleal hematoma|subgaleal, hematoma

# %%
cui_lsts[0] = ['C0238154',
            'C0877172',
            'C2832464',
            'C2832428',
            'C0472385',
            'C0474997',
            'C2062695']

# %%
cui_lsts[1] = ['C0018946',
             'C0270087',
             'C0393494',
             'C0393495',
             'C0238156',
             'C0265080',
             'C0749095',
             'C0749098',
             'C0854700',
             'C1367166']

# %%
cui_lsts[2] = ['C3552968'
            'C3698285'
            'C0475010'
            'C2316496']

# %%
errs = [None for i in range(7)]

# %%
def dsr_cui(_dsrs, cuis):
    return int(any([_cui in cuis for _cui in _dsrs.split(' ')]))

# %%
for i in range(7): # Create Dataframes of which entries were incorrectly classified.
    dtt[mtm_abbs[i]] = dtt['dsrs'].apply(lambda _dsrs : dsr_cui(_dsrs, cui_lsts[i]))
    tmp = dtt[dtt[mtm_abbs[i]]!=dtt[abbs[i]]].copy()
    tmp['flt'] = tmp['rpr'].apply(lambda _x:kyw_flt(abb_exp(_x, abbs, dsrs), dsrs[i]))
    errs[i] = tmp[['flt', abbs[i], mtm_abbs[i]]]

# %%
dtt.to_csv('mtm.csv', encoding='latin-1', index=False, quoting=csv.QUOTE_NONNUMERIC)

# %% [markdown]
# ### Accuracies

# %%
for i in range(7):
    print(dsrs[i])
    print(numpy.round(1-len(errs[i])/len(dtt), 2))
    print()
# Out:
# epidural hematoma
# 1.0
#
# subdural hematoma
# 0.96
#
# intraparenchymal hemorrhage
# 0.71
#
# contusion
# 0.91
#
# subarachnoid hemorrhage
# 0.82
#
# intraventricular hemorrhage
# 0.89
#
# subgaleal hematoma
# 0.93

# %% [markdown]
# ### Review of Errors

# %%
errs[0]
# Out:
# Empty DataFrame
# Columns: [flt, eph, mtm_eph]
# Index: []

# %%
errs[1]
# Out:
#                                                                                                                                                                                                                      flt  \
# 32  left temporal intraparenchymal contusion with subarachnoid and subdural extension and surrounding vasogenic edema causing mass effect and left hemispheric brain edema
# 41  no significant changes of the bilateral holohemispheric subdural hematomas with supratentorial extension
# 64  clinical information : { age _ number } year - old woman fu subarachnoid hemorrhage / subdural hematoma please do ct head at 10 : 00 am
# 71  the previously described small subdural collection over the right paracentral lobule has decreased in size . there is no significant widening of the subarachnoid or subdural space over the left cerebral convexity
#
#     sdh  mtm_sdh
# 32  1    0
# 41  1    0
# 64  0    1
# 71  1    0

# %%
errs[2]
# Out:
#                                                                                                                                                                                                   flt  \
# 0   left inferior parietal small subarachnoid / intraparenchymal bleed
# 4   presence of at least 5 foci of intraparenchymal hemorrhage surrounded by vasogenic edema with the largest measuring 1. bilateral intraparenchymal contusions
# 10
# 15
# 33
# 36
# 42
# 43  the intraparenchymal hematomas compatible with areas of hemorrhagic contusion in the temporal lobes and in the frontal lobe demonstrate stable morphology in comparison with previous examination
# 44  intraparenchymal hematomas compatible with areas of hemorrhagic contusion in both temporal lobes
# 45
# 46
# 47  findings : large left temporoparietal intraparenchymal hemorrhage with slight spilling into adjacent subarachnoid space this . impression : large left hemispheric intraparenchymal bleed
# 48
# 50
# 51
# 56
# 57
# 60
# 64
# 65
# 66
# 74
# 75
# 76
# 79
# 81  intraparenchymal versus subarachnoid
# 84
# 85
# 87
#
#     iph  mtm_iph
# 0   1    0
# 4   1    0
# 10  1    0
# 15  1    0
# 33  1    0
# 36  1    0
# 42  1    0
# 43  1    0
# 44  1    0
# 45  1    0
# 46  1    0
# 47  1    0
# 48  1    0
# 50  1    0
# 51  1    0
# 56  1    0
# 57  1    0
# 60  1    0
# 64  1    0
# 65  1    0
# 66  1    0
# 74  1    0
# 75  1    0
# 76  1    0
# 79  1    0
# 81  1    0
# 84  1    0
# 85  1    0
# 87  1    0

# %%
errs[3]
# Out:
#                                                                                                                                                                                             flt  \
# 0   bifrontal multiple hemorrhagic contusions involving the inferior surface of the right frontal lobe extending into both supraorbital gyri
# 29  more probably subarachnoid bleed but possibly cortical hemorrhagic contusion
# 40  suggestive of hemorrhagic contusion
# 56  left frontal supraorbital hemorrhagic contusions . multi compartmental traumatic bleed with subarachnoid hemorrhage and left supraorbital and right superior frontal hemorrhagic contusions
# 57  small focal areas of brain parenchymal hemorrhagic contusion involving the left inferior and medial temporal gyri and the left gyrus rectus
# 79  likely cortical contusion
# 84
# 89  unchanged left frontal hemorrhagic parenchymal contusion
# 91  no interval significant change in the left frontal hemorrhagic parenchymal contusion
#
#     cnt  mtm_cnt
# 0   1    0
# 29  1    0
# 40  0    1
# 56  0    1
# 57  1    0
# 79  1    0
# 84  1    0
# 89  1    0
# 91  1    0

# %%
errs[4]
# Out:
#                                                                                                                                                                                                                                                              flt  \
# 1   note : small posttraumatic subarachnoid bleed could be missed in the presence of recent intravenous contrast injection
# 7   acute confusion hx of subarachnoid hemorrhage
# 8   clinical information : { age _ number } years old r / o subarachnoid hemorrhage
# 14  focal intra - axial subarachnoid hyperdensity involving the left inferior frontal sulcus . focal extra - axial subarachnoid hyperdensity involving the left inferior frontal sulcus . however is not possible to completely rule out subarachnoid hemorrhage
# 21  interval resolution of the subarachnoid hemorrhage . follow - up study with interval resolution of the subarachnoid hemorrhage and expected evolution of the right temporoparietal subdural hematoma
# 23  no evidence of new subarachnoid hemorrhage
# 28  acute subarachnoid bleed in the in the middle left temporal gyrus area
# 32  left temporal intraparenchymal contusion with subarachnoid and subdural extension and surrounding vasogenic edema causing mass effect and left hemispheric brain edema
# 34  small right subarachnoid and interhemispheric subdural falcine hematoma
# 37  o subarachnoid bleed
# 47  findings : large left temporoparietal intraparenchymal hemorrhage with slight spilling into adjacent subarachnoid space this
# 63  clinical information : 88 m with previous stable subarachnoid hemorrhage following ffoh in march
# 69  the subarachnoid spaces over the convexities are unremarkable
# 74  clinical information : { age _ number } years old fu subarachnoid hemorrhage
# 81  intraparenchymal versus subarachnoid
# 83  clinical information : { age _ number } years old subarachnoid hemorrhage
# 95  associated subarachnoid hemorrhage should be considered
# 98  clinical information : { age _ number } year - old man f / u subarachnoid
#
#     sah  mtm_sah
# 1   0    1
# 7   0    1
# 8   0    1
# 14  1    0
# 21  0    1
# 23  1    0
# 28  1    0
# 32  1    0
# 34  1    0
# 37  1    0
# 47  1    0
# 63  0    1
# 69  1    0
# 74  0    1
# 81  1    0
# 83  0    1
# 95  0    1
# 98  1    0

# %%
errs[5]
# Out:
#                                                                                                                                                                                                                                      flt  \
# 11  subarachnoid hemorrhage with intraventricular extension
# 12  with mild intraventricular extension . traumatic subarachnoid hemorrhage with intraventricular extension
# 41  with mild increase in the intraventricular component of the subarachnoid hemorrhage . follow - up study with mild increase in the intraventricular component of the subarachnoid hemorrhage
# 42  traumatic subarachnoid hemorrhage with intraventricular extension and no hydrocepidural hematomaalus . traumatic subarachnoid hemorrhage with intraventricular extension
# 43  stable a small amount of intraventricular hemorrhage in the occipital horn of the right lateral ventricle
# 46
# 60  large mostly infratentorial diffuse subarachnoid hemorrhage with intraventricular extension
# 69  small to moderate amount of intraventricular blood layering in the occipital horns and atria of the lateral ventricles . there is also intraventricular clot in the left lateral ventricle . stable amount of intraventricular blood
# 76
# 77
# 94
#
#     ivh  mtm_ivh
# 11  1    0
# 12  1    0
# 41  1    0
# 42  1    0
# 43  0    1
# 46  1    0
# 60  1    0
# 69  1    0
# 76  1    0
# 77  1    0
# 94  1    0

# %%
errs[6]
# Out:
#                                                                                                                                                                     flt  \
# 5   right parietal subgaleal hematoma and emphysema with no evidence of underlying fracture . right parietal subgaleal hematoma with no evidence of underlying fracture
# 31  right subgaleal occipital hematoma underlying the linear nondisplaced occipital fracture
# 46
# 51  right parietal subgaleal hematoma
# 59  left temporal subgaleal hematoma
# 77  left parietal acute subgaleal hematoma with no underlying fracture
# 90  thin subgaleal hematoma overlying the left parieto - occipital fracture
#
#     sgh  mtm_sgh
# 5   0    1
# 31  0    1
# 46  1    0
# 51  0    1
# 59  0    1
# 77  0    1
# 90  0    1
